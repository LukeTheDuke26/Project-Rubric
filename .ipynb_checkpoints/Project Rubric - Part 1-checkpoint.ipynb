# %% [raw]
# Part 1 - Project Rubric: Analysis of the Stack Overflow 2017 Developer Survey
#
# This notebook presents a comprehensive analysis of the StackOverflow's 2017 Developer Survey. The aim is to delve into the life and preferences of Developers and explore various facets of their journey, including their education, skill development, tool usage, work environment, outcomes, satisfaction, and their engagement with the StackOverflow community.
#
# We'll be focusing our analysis on three major categories:
#
# Education and Skill Development: The Birth of a Developer
# We will investigate the sources of knowledge and skill acquisition among developers, their educational backgrounds, and their pathways into the field.
# (A.) Where do most developers acquire their skills and knowledge?
# (B.) What educational background do they come from?
#
# Code Nation Chronicles: Unraveling the Developer's Universe
# (C.) How many respondents program as a hobby or contribute to open source projects?
# (D.) What is the distribution of programming hobbies in the top 10 countries with the most respondents?
# (E.) How is the distribution of programming experience among the survey respondents?
#
# Technology and Tools: The Developer's Magic Wand
# Here, we'll discover the most popular programming languages, databases, platforms, and development environments among developers.
# (F.) What programming languages are most popular among developers?
# (G.) What platforms and databases do they primarily work with?
# (H.) Which development environments (IDEs) do they prefer?
#
# Work Environment and Preferences: The Developer's Shire
# We aim to gain insights into the typical working environments of developers, including the size and type of organizations they work for, their work hours, job
# satisfaction, and remote work frequency.
# (I.) What is the size and type of organizations developers work for?
# (J.) What are their working hours and job satisfaction levels?
# (K.) How often do they work remotely?
# (L.) How much is Job Satisfaction influenced by factors such as working hours,career satisfaction and salary?

# %% [raw]
# Step 1: Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Configure pandas to display all columns/rows as needed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


df = pd.read_csv('/Users/luca/Documents/Project Rubric/Data Part 1/survey_results_public.csv')

# %% [raw]
# Step 2: Initial Data Exploration

# %%
# Display the first 5 rows
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  \
# 0                       NaN
# 1        20 to 99 employees
# 2  10,000 or more employees
# 3  10,000 or more employees
# 4        10 to 19 employees
#
#                                          CompanyType      YearsProgram  \
# 0                                                NaN      2 to 3 years
# 1  Privately-held limited company, not in startup...     9 to 10 years
# 2                        Publicly-traded corporation  20 or more years
# 3  Non-profit/non-governmental organization or pr...    14 to 15 years
# 4  Privately-held limited company, not in startup...  20 or more years
#
#       YearsCodedJob YearsCodedJobPast  \
# 0               NaN               NaN
# 1               NaN               NaN
# 2  20 or more years               NaN
# 3     9 to 10 years               NaN
# 4    10 to 11 years               NaN
#
#                                        DeveloperType WebDeveloperType  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                              Other              NaN
# 3                                                NaN              NaN
# 4  Mobile developer; Graphics programming; Deskto...              NaN
#
#   MobileDeveloperType NonDeveloperType  CareerSatisfaction  JobSatisfaction  \
# 0                 NaN              NaN                 NaN              NaN
# 1                 NaN              NaN                 NaN              NaN
# 2                 NaN              NaN                 8.0              9.0
# 3                 NaN   Data scientist                 6.0              3.0
# 4                 NaN              NaN                 6.0              8.0
#
#   ExCoderReturn ExCoderNotForMe ExCoderBalance ExCoder10Years ExCoderBelonged  \
# 0           NaN             NaN            NaN            NaN             NaN
# 1           NaN             NaN            NaN            NaN             NaN
# 2           NaN             NaN            NaN            NaN             NaN
# 3           NaN             NaN            NaN            NaN             NaN
# 4           NaN             NaN            NaN            NaN             NaN
#
#   ExCoderSkills ExCoderWillNotCode ExCoderActive  \
# 0           NaN                NaN           NaN
# 1           NaN                NaN           NaN
# 2           NaN                NaN           NaN
# 3           NaN                NaN           NaN
# 4           NaN                NaN           NaN
#
#                    PronounceGIF  ProblemSolving  BuildingThings  \
# 0  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 1  With a hard "g," like "gift"             NaN             NaN
# 2  With a hard "g," like "gift"  Strongly agree  Strongly agree
# 3  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 4  With a soft "g," like "jiff"             NaN             NaN
#
#   LearningNewTech   BoringDetails     JobSecurity DiversityImportant  \
# 0           Agree        Disagree  Strongly agree              Agree
# 1             NaN             NaN             NaN                NaN
# 2  Strongly agree  Somewhat agree           Agree     Strongly agree
# 3  Strongly agree        Disagree  Somewhat agree              Agree
# 4             NaN             NaN             NaN                NaN
#
#   AnnoyingUI FriendsDevelopers   RightWrongWay UnderstandComputers  \
# 0      Agree          Disagree  Somewhat agree            Disagree
# 1        NaN               NaN             NaN                 NaN
# 2      Agree    Somewhat agree        Disagree            Disagree
# 3      Agree             Agree  Somewhat agree   Strongly disagree
# 4        NaN               NaN             NaN                 NaN
#
#       SeriousWork InvestTimeTools        WorkPayCare KinshipDevelopers  \
# 0  Strongly agree  Strongly agree  Strongly disagree             Agree
# 1             NaN             NaN                NaN               NaN
# 2           Agree  Somewhat agree           Disagree    Somewhat agree
# 3  Strongly agree           Agree           Disagree    Strongly agree
# 4             NaN             NaN                NaN               NaN
#
#   ChallengeMyself    CompetePeers ChangeWorld  \
# 0           Agree        Disagree       Agree
# 1             NaN             NaN         NaN
# 2           Agree        Disagree       Agree
# 3  Strongly agree  Somewhat agree       Agree
# 4             NaN             NaN         NaN
#
#                                     JobSeekingStatus  HoursPerWeek  \
# 0  I'm not actively looking, but I am open to new...           0.0
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                    I am actively looking for a job           5.0
# 4                                                NaN           NaN
#
#                   LastNewJob   AssessJobIndustry       AssessJobRole  \
# 0      Not applicable/ never      Very important      Very important
# 1                        NaN                 NaN                 NaN
# 2                        NaN                 NaN                 NaN
# 3  Between 2 and 4 years ago  Somewhat important  Somewhat important
# 4                        NaN                 NaN                 NaN
#
#          AssessJobExp   AssessJobDept   AssessJobTech AssessJobProjects  \
# 0           Important  Very important  Very important    Very important
# 1                 NaN             NaN             NaN               NaN
# 2                 NaN             NaN             NaN               NaN
# 3  Somewhat important       Important       Important    Very important
# 4                 NaN             NaN             NaN               NaN
#
#   AssessJobCompensation AssessJobOffice AssessJobCommute     AssessJobRemote  \
# 0             Important  Very important   Very important      Very important
# 1                   NaN             NaN              NaN                 NaN
# 2                   NaN             NaN              NaN                 NaN
# 3             Important  Very important        Important  Somewhat important
# 4                   NaN             NaN              NaN                 NaN
#
#      AssessJobLeaders AssessJobProfDevel  AssessJobDiversity  \
# 0      Very important     Very important  Somewhat important
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3  Not very important     Very important           Important
# 4                 NaN                NaN                 NaN
#
#      AssessJobProduct   AssessJobFinances  \
# 0  Not very important  Somewhat important
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3      Very important      Very important
# 4                 NaN                 NaN
#
#                                    ImportantBenefits ClickyKeys  \
# 0   Stock options; Vacation/days off; Remote options        Yes
# 1                                                NaN         No
# 2                                                NaN        Yes
# 3  Stock options; Annual bonus; Health benefits; ...        Yes
# 4                                                NaN        NaN
#
#         JobProfile ResumePrompted  \
# 0            Other            NaN
# 1            Other            NaN
# 2              NaN            NaN
# 3  LinkedIn; Other            NaN
# 4              NaN            NaN
#
#                                        LearnedHiring  \
# 0                                                NaN
# 1                                     Some other way
# 2                                                NaN
# 3  A friend, family member, or former colleague t...
# 4                                                NaN
#
#   ImportantHiringAlgorithms ImportantHiringTechExp  \
# 0                 Important              Important
# 1                 Important              Important
# 2                       NaN                    NaN
# 3        Somewhat important     Somewhat important
# 4                       NaN                    NaN
#
#   ImportantHiringCommunication ImportantHiringOpenSource ImportantHiringPMExp  \
# 0                    Important        Somewhat important            Important
# 1                    Important                 Important   Somewhat important
# 2                          NaN                       NaN                  NaN
# 3               Very important            Very important   Somewhat important
# 4                          NaN                       NaN                  NaN
#
#   ImportantHiringCompanies ImportantHiringTitles ImportantHiringEducation  \
# 0       Not very important    Not very important     Not at all important
# 1       Somewhat important    Not very important       Somewhat important
# 2                      NaN                   NaN                      NaN
# 3       Somewhat important    Not very important       Not very important
# 4                      NaN                   NaN                      NaN
#
#    ImportantHiringRep ImportantHiringGettingThingsDone  \
# 0  Somewhat important                   Very important
# 1  Not very important                   Very important
# 2                 NaN                              NaN
# 3           Important                   Very important
# 4                 NaN                              NaN
#
#                       Currency                        Overpaid TabsSpaces  \
# 0                          NaN                             NaN       Tabs
# 1  British pounds sterling (£)                             NaN     Spaces
# 2  British pounds sterling (£)  Neither underpaid nor overpaid     Spaces
# 3                          NaN                             NaN     Spaces
# 4                          NaN                             NaN        NaN
#
#    EducationImportant                                     EducationTypes  \
# 0                 NaN           Online course; Open source contributions
# 1                 NaN  Online course; Self-taught; Hackathon; Open so...
# 2  Not very important  Self-taught; Coding competition; Hackathon; Op...
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#                                      SelfTaughtTypes TimeAfterBootcamp  \
# 0                                                NaN               NaN
# 1  Official documentation; Stack Overflow Q&A; Other               NaN
# 2  Official documentation; Trade book; Textbook; ...               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#   CousinEducation WorkStart             HaveWorkedLanguage  \
# 0             NaN   6:00 AM                          Swift
# 1             NaN  10:00 AM  JavaScript; Python; Ruby; SQL
# 2             NaN   9:00 AM              Java; PHP; Python
# 3             NaN   9:00 AM         Matlab; Python; R; SQL
# 4             NaN       NaN                            NaN
#
#           WantWorkLanguage HaveWorkedFramework       WantWorkFramework  \
# 0                    Swift                 NaN                     NaN
# 1  Java; Python; Ruby; SQL           .NET Core               .NET Core
# 2          C; Python; Rust                 NaN                     NaN
# 3   Matlab; Python; R; SQL               React  Hadoop; Node.js; React
# 4                      NaN                 NaN                     NaN
#
#                           HaveWorkedDatabase  \
# 0                                        NaN
# 1                              MySQL; SQLite
# 2                                      MySQL
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite
# 4                                        NaN
#
#                             WantWorkDatabase  \
# 0                                        NaN
# 1                              MySQL; SQLite
# 2                                        NaN
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite
# 4                                        NaN
#
#                                   HaveWorkedPlatform  \
# 0                                                iOS
# 1                          Amazon Web Services (AWS)
# 2                                                NaN
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...
# 4                                                NaN
#
#                                     WantWorkPlatform  \
# 0                                                iOS
# 1  Linux Desktop; Raspberry Pi; Amazon Web Servic...
# 2                                                NaN
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...
# 4                                                NaN
#
#                                                  IDE  \
# 0                                        Atom; Xcode
# 1  Atom; Notepad++; Vim; PyCharm; RubyMine; Visua...
# 2                        Sublime Text; Vim; IntelliJ
# 3  Notepad++; Sublime Text; TextMate; Vim; IPytho...
# 4                                                NaN
#
#                                  AuditoryEnvironment  \
# 0                                 Turn on some music
# 1  Put on some ambient sounds (e.g. whale songs, ...
# 2                                 Turn on some music
# 3                                 Turn on some music
# 4                                                NaN
#
#                                  Methodology VersionControl  \
# 0                                        NaN            NaN
# 1                                        NaN            Git
# 2  Agile; Lean; Scrum; Extreme; Pair; Kanban      Mercurial
# 3                                      Agile            Git
# 4                                        NaN            NaN
#
#             CheckInCode          ShipIt OtherPeoplesCode  ProjectManagement  \
# 0                   NaN             NaN              NaN                NaN
# 1  Multiple times a day           Agree         Disagree  Strongly disagree
# 2  Multiple times a day           Agree         Disagree           Disagree
# 3  Multiple times a day  Somewhat agree            Agree     Somewhat agree
# 4                   NaN             NaN              NaN                NaN
#
#    EnjoyDebugging       InTheZone DifficultCommunication  CollaborateRemote  \
# 0             NaN             NaN                    NaN                NaN
# 1           Agree  Somewhat agree               Disagree  Strongly disagree
# 2           Agree           Agree               Disagree     Somewhat agree
# 3  Somewhat agree  Strongly agree               Disagree     Somewhat agree
# 4             NaN             NaN                    NaN                NaN
#
#                                         MetricAssess  \
# 0                                                NaN
# 1  Customer satisfaction; On time/in budget; Peer...
# 2  Customer satisfaction; Benchmarked product per...
# 3                                                NaN
# 4                                                NaN
#
#   EquipmentSatisfiedMonitors EquipmentSatisfiedCPU EquipmentSatisfiedRAM  \
# 0         Somewhat satisfied    Not very satisfied  Not at all satisfied
# 1         Not very satisfied             Satisfied             Satisfied
# 2             Very satisfied    Somewhat satisfied             Satisfied
# 3                        NaN                   NaN                   NaN
# 4                  Satisfied             Satisfied             Satisfied
#
#   EquipmentSatisfiedStorage EquipmentSatisfiedRW   InfluenceInternet  \
# 0            Very satisfied            Satisfied  Not very satisfied
# 1                 Satisfied   Somewhat satisfied           Satisfied
# 2                 Satisfied   Somewhat satisfied      Very satisfied
# 3                       NaN                  NaN                 NaN
# 4                 Satisfied            Satisfied           Satisfied
#
#   InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2   A lot of influence       Some influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#     InfluenceTechStack    InfluenceDeptTech    InfluenceVizTools  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2       Some influence   A lot of influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#      InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# 0                  NaN                  NaN                  NaN
# 1  No influence at all  No influence at all  No influence at all
# 2       Some influence       Some influence       Some influence
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   InfluenceRecruitment InfluenceCommunication  \
# 0                  NaN                    NaN
# 1  No influence at all    No influence at all
# 2       Some influence         Some influence
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                               StackOverflowDescribes  \
# 0  I have created a CV or Developer Story on Stac...
# 1  I have created a CV or Developer Story on Stac...
# 2  I have created a CV or Developer Story on Stac...
# 3  I have created a CV or Developer Story on Stac...
# 4                                                NaN
#
#    StackOverflowSatisfaction  \
# 0                        9.0
# 1                        8.0
# 2                        8.0
# 3                       10.0
# 4                        NaN
#
#                                 StackOverflowDevices StackOverflowFoundAnswer  \
# 0                                   Desktop; iOS app  At least once each week
# 1  Desktop; iOS browser; iOS app; Android browser...            Several times
# 2                      Desktop; iOS browser; iOS app            Once or twice
# 3                      Desktop; iOS browser; iOS app  At least once each week
# 4                                                NaN                      NaN
#
#   StackOverflowCopiedCode  StackOverflowJobListing StackOverflowCompanyPage  \
# 0     Haven't done at all            Once or twice      Haven't done at all
# 1           Several times            Once or twice            Once or twice
# 2     Haven't done at all      Haven't done at all      Haven't done at all
# 3           Several times  At least once each week            Several times
# 4                     NaN                      NaN                      NaN
#
#     StackOverflowJobSearch StackOverflowNewQuestion     StackOverflowAnswer  \
# 0      Haven't done at all            Several times           Several times
# 1            Once or twice      Haven't done at all           Several times
# 2      Haven't done at all      Haven't done at all  At least once each day
# 3  At least once each week            Several times  At least once each day
# 4                      NaN                      NaN                     NaN
#
#      StackOverflowMetaChat StackOverflowAdsRelevant  \
# 0            Once or twice           Somewhat agree
# 1  At least once each week                 Disagree
# 2   At least once each day                 Disagree
# 3   At least once each day                    Agree
# 4                      NaN                      NaN
#
#   StackOverflowAdsDistracting StackOverflowModeration StackOverflowCommunity  \
# 0           Strongly disagree       Strongly disagree         Strongly agree
# 1           Strongly disagree       Strongly disagree         Strongly agree
# 2                    Disagree       Strongly disagree         Strongly agree
# 3           Strongly disagree       Strongly disagree         Strongly agree
# 4                         NaN                     NaN                    NaN
#
#   StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# 0                Agree      Strongly agree      Strongly agree
# 1                Agree      Strongly agree      Strongly agree
# 2                Agree               Agree               Agree
# 3       Strongly agree               Agree      Strongly agree
# 4                  NaN                 NaN                 NaN
#
#   StackOverflowMakeMoney Gender HighestEducationParents  \
# 0      Strongly disagree   Male             High school
# 1      Strongly disagree   Male       A master's degree
# 2               Disagree   Male   A professional degree
# 3               Disagree   Male       A doctoral degree
# 4                    NaN    NaN                     NaN
#
#                            Race         SurveyLong QuestionsInteresting  \
# 0  White or of European descent  Strongly disagree       Strongly agree
# 1  White or of European descent     Somewhat agree       Somewhat agree
# 2  White or of European descent     Somewhat agree                Agree
# 3  White or of European descent              Agree                Agree
# 4                           NaN                NaN                  NaN
#
#   QuestionsConfusing InterestedAnswers    Salary  ExpectedSalary
# 0           Disagree    Strongly agree       NaN             NaN
# 1           Disagree    Strongly agree       NaN         37500.0
# 2           Disagree             Agree  113750.0             NaN
# 3     Somewhat agree    Strongly agree       NaN             NaN
# 4                NaN               NaN       NaN             NaN

# %%
# Concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19102 entries, 0 to 19101
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 22.4+ MB

# %%
# Descriptive statistics for all columns, including object and categorical dtype, to get a first idea of the df
df.describe(include='all')
# Out:
#           Respondent            Professional               ProgramHobby  \
# count   19102.000000                   19102                      19102
# unique           NaN                       5                          4
# top              NaN  Professional developer  Yes, I program as a hobby
# freq             NaN                   13774                       9260
# mean     9551.500000                     NaN                        NaN
# std      5514.416757                     NaN                        NaN
# min         1.000000                     NaN                        NaN
# 25%      4776.250000                     NaN                        NaN
# 50%      9551.500000                     NaN                        NaN
# 75%     14326.750000                     NaN                        NaN
# max     19102.000000                     NaN                        NaN
#
#               Country University    EmploymentStatus    FormalEducation  \
# count           19102      19102               19102              19102
# unique            165          4                   7                  9
# top     United States         No  Employed full-time  Bachelor's degree
# freq             4364      14233               13655               8099
# mean              NaN        NaN                 NaN                NaN
# std               NaN        NaN                 NaN                NaN
# min               NaN        NaN                 NaN                NaN
# 25%               NaN        NaN                 NaN                NaN
# 50%               NaN        NaN                 NaN                NaN
# 75%               NaN        NaN                 NaN                NaN
# max               NaN        NaN                 NaN                NaN
#
#                                   MajorUndergrad             HomeRemote  \
# count                                      15899                  16471
# unique                                        16                      7
# top     Computer science or software engineering  A few days each month
# freq                                        8098                   5876
# mean                                         NaN                    NaN
# std                                          NaN                    NaN
# min                                          NaN                    NaN
# 25%                                          NaN                    NaN
# 50%                                          NaN                    NaN
# 75%                                          NaN                    NaN
# max                                          NaN                    NaN
#
#                CompanySize                                        CompanyType  \
# count                14653                                              14609
# unique                  10                                                 11
# top     20 to 99 employees  Privately-held limited company, not in startup...
# freq                  3214                                               6283
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#             YearsProgram YearsCodedJob YearsCodedJobPast  DeveloperType  \
# count              19005         15391               349          13772
# unique                21            21                21           1024
# top     20 or more years  1 to 2 years  20 or more years  Web developer
# freq                3471          1867                67           4283
# mean                 NaN           NaN               NaN            NaN
# std                  NaN           NaN               NaN            NaN
# min                  NaN           NaN               NaN            NaN
# 25%                  NaN           NaN               NaN            NaN
# 50%                  NaN           NaN               NaN            NaN
# 75%                  NaN           NaN               NaN            NaN
# max                  NaN           NaN               NaN            NaN
#
#                 WebDeveloperType MobileDeveloperType NonDeveloperType  \
# count                       4286                 556             1688
# unique                         3                   8               86
# top     Full stack Web developer             Android            Other
# freq                        2729                 220              450
# mean                         NaN                 NaN              NaN
# std                          NaN                 NaN              NaN
# min                          NaN                 NaN              NaN
# 25%                          NaN                 NaN              NaN
# 50%                          NaN                 NaN              NaN
# 75%                          NaN                 NaN              NaN
# max                          NaN                 NaN              NaN
#
#         CareerSatisfaction  JobSatisfaction ExCoderReturn    ExCoderNotForMe  \
# count         16102.000000     15253.000000           335                332
# unique                 NaN              NaN             5                  5
# top                    NaN              NaN         Agree  Strongly disagree
# freq                   NaN              NaN            87                121
# mean              7.343932         7.000721           NaN                NaN
# std               1.919330         2.128648           NaN                NaN
# min               0.000000         0.000000           NaN                NaN
# 25%               6.000000         6.000000           NaN                NaN
# 50%               8.000000         7.000000           NaN                NaN
# 75%               9.000000         8.000000           NaN                NaN
# max              10.000000        10.000000           NaN                NaN
#
#        ExCoderBalance ExCoder10Years ExCoderBelonged   ExCoderSkills  \
# count             335            336             335             336
# unique              5              5               5               5
# top          Disagree       Disagree        Disagree  Somewhat agree
# freq              100             93             129              94
# mean              NaN            NaN             NaN             NaN
# std               NaN            NaN             NaN             NaN
# min               NaN            NaN             NaN             NaN
# 25%               NaN            NaN             NaN             NaN
# 50%               NaN            NaN             NaN             NaN
# 75%               NaN            NaN             NaN             NaN
# max               NaN            NaN             NaN             NaN
#
#        ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# count                 332           335                         18940
# unique                  5             5                             4
# top              Disagree         Agree  With a hard "g," like "gift"
# freq                  107           110                         12694
# mean                  NaN           NaN                           NaN
# std                   NaN           NaN                           NaN
# min                   NaN           NaN                           NaN
# 25%                   NaN           NaN                           NaN
# 50%                   NaN           NaN                           NaN
# 75%                   NaN           NaN                           NaN
# max                   NaN           NaN                           NaN
#
#         ProblemSolving  BuildingThings LearningNewTech BoringDetails  \
# count            12220           12201           12216         12190
# unique               5               5               5             5
# top     Strongly agree  Strongly agree  Strongly agree      Disagree
# freq              6941            6662            5711          4808
# mean               NaN             NaN             NaN           NaN
# std                NaN             NaN             NaN           NaN
# min                NaN             NaN             NaN           NaN
# 25%                NaN             NaN             NaN           NaN
# 50%                NaN             NaN             NaN           NaN
# 75%                NaN             NaN             NaN           NaN
# max                NaN             NaN             NaN           NaN
#
#        JobSecurity DiversityImportant      AnnoyingUI FriendsDevelopers  \
# count        12198              12079           12140             12143
# unique           5                  5               5                 5
# top          Agree              Agree  Strongly agree          Disagree
# freq          5208               4738            4855              3740
# mean           NaN                NaN             NaN               NaN
# std            NaN                NaN             NaN               NaN
# min            NaN                NaN             NaN               NaN
# 25%            NaN                NaN             NaN               NaN
# 50%            NaN                NaN             NaN               NaN
# 75%            NaN                NaN             NaN               NaN
# max            NaN                NaN             NaN               NaN
#
#          RightWrongWay UnderstandComputers SeriousWork InvestTimeTools  \
# count            12112               12135       12132           12059
# unique               5                   5           5               5
# top     Somewhat agree            Disagree       Agree           Agree
# freq              3888                3137        5902            4827
# mean               NaN                 NaN         NaN             NaN
# std                NaN                 NaN         NaN             NaN
# min                NaN                 NaN         NaN             NaN
# 25%                NaN                 NaN         NaN             NaN
# 50%                NaN                 NaN         NaN             NaN
# 75%                NaN                 NaN         NaN             NaN
# max                NaN                 NaN         NaN             NaN
#
#        WorkPayCare KinshipDevelopers ChallengeMyself CompetePeers  \
# count        12087             11980           12089        12034
# unique           5                 5               5            5
# top       Disagree             Agree           Agree     Disagree
# freq          5570              5048            5839         3956
# mean           NaN               NaN             NaN          NaN
# std            NaN               NaN             NaN          NaN
# min            NaN               NaN             NaN          NaN
# 25%            NaN               NaN             NaN          NaN
# 50%            NaN               NaN             NaN          NaN
# 75%            NaN               NaN             NaN          NaN
# max            NaN               NaN             NaN          NaN
#
#            ChangeWorld                                   JobSeekingStatus  \
# count            12077                                              12852
# unique               5                                                  3
# top     Somewhat agree  I'm not actively looking, but I am open to new...
# freq              3754                                               8026
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#         HoursPerWeek            LastNewJob AssessJobIndustry AssessJobRole  \
# count    7721.000000                 12578              8401          8403
# unique           NaN                     5                 5             5
# top              NaN  Less than a year ago         Important     Important
# freq             NaN                  3798              2760          3164
# mean        3.685922                   NaN               NaN           NaN
# std         7.330691                   NaN               NaN           NaN
# min         0.000000                   NaN               NaN           NaN
# 25%         0.000000                   NaN               NaN           NaN
# 50%         1.000000                   NaN               NaN           NaN
# 75%         3.000000                   NaN               NaN           NaN
# max        40.000000                   NaN               NaN           NaN
#
#        AssessJobExp AssessJobDept AssessJobTech AssessJobProjects  \
# count          8398          8390          8420              8412
# unique            5             5             5                 5
# top       Important     Important     Important         Important
# freq           3790          3307          3503              3722
# mean            NaN           NaN           NaN               NaN
# std             NaN           NaN           NaN               NaN
# min             NaN           NaN           NaN               NaN
# 25%             NaN           NaN           NaN               NaN
# 50%             NaN           NaN           NaN               NaN
# 75%             NaN           NaN           NaN               NaN
# max             NaN           NaN           NaN               NaN
#
#        AssessJobCompensation AssessJobOffice AssessJobCommute  \
# count                   8407            8336             8331
# unique                     5               5                5
# top                Important       Important        Important
# freq                    3779            3815             3208
# mean                     NaN             NaN              NaN
# std                      NaN             NaN              NaN
# min                      NaN             NaN              NaN
# 25%                      NaN             NaN              NaN
# 50%                      NaN             NaN              NaN
# 75%                      NaN             NaN              NaN
# max                      NaN             NaN              NaN
#
#            AssessJobRemote AssessJobLeaders AssessJobProfDevel  \
# count                 8351             8330               8341
# unique                   5                5                  5
# top     Somewhat important        Important          Important
# freq                  2347             2817               3575
# mean                   NaN              NaN                NaN
# std                    NaN              NaN                NaN
# min                    NaN              NaN                NaN
# 25%                    NaN              NaN                NaN
# 50%                    NaN              NaN                NaN
# 75%                    NaN              NaN                NaN
# max                    NaN              NaN                NaN
#
#         AssessJobDiversity AssessJobProduct AssessJobFinances  \
# count                 8324             8334              8351
# unique                   5                5                 5
# top     Somewhat important        Important         Important
# freq                  2611             2947              3364
# mean                   NaN              NaN               NaN
# std                    NaN              NaN               NaN
# min                    NaN              NaN               NaN
# 25%                    NaN              NaN               NaN
# 50%                    NaN              NaN               NaN
# 75%                    NaN              NaN               NaN
# max                    NaN              NaN               NaN
#
#        ImportantBenefits ClickyKeys JobProfile  \
# count              11570      15358       9190
# unique              2432          2        270
# top        None of these        Yes   LinkedIn
# freq                 248       8297       5660
# mean                 NaN        NaN        NaN
# std                  NaN        NaN        NaN
# min                  NaN        NaN        NaN
# 25%                  NaN        NaN        NaN
# 50%                  NaN        NaN        NaN
# 75%                  NaN        NaN        NaN
# max                  NaN        NaN        NaN
#
#                                ResumePrompted  \
# count                                    8704
# unique                                      8
# top     I was just giving it a regular update
# freq                                     2693
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#                                             LearnedHiring  \
# count                                                9183
# unique                                                  8
# top     A friend, family member, or former colleague t...
# freq                                                 2520
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        ImportantHiringAlgorithms ImportantHiringTechExp  \
# count                      10890                  10894
# unique                         5                      5
# top                    Important              Important
# freq                        4463                   4030
# mean                         NaN                    NaN
# std                          NaN                    NaN
# min                          NaN                    NaN
# 25%                          NaN                    NaN
# 50%                          NaN                    NaN
# 75%                          NaN                    NaN
# max                          NaN                    NaN
#
#        ImportantHiringCommunication ImportantHiringOpenSource  \
# count                         10879                     10864
# unique                            5                         5
# top                       Important        Somewhat important
# freq                           4991                      4075
# mean                            NaN                       NaN
# std                             NaN                       NaN
# min                             NaN                       NaN
# 25%                             NaN                       NaN
# 50%                             NaN                       NaN
# 75%                             NaN                       NaN
# max                             NaN                       NaN
#
#        ImportantHiringPMExp ImportantHiringCompanies ImportantHiringTitles  \
# count                 10869                    10851                 10859
# unique                    5                        5                     5
# top      Somewhat important       Somewhat important    Somewhat important
# freq                   3864                     4487                  4075
# mean                    NaN                      NaN                   NaN
# std                     NaN                      NaN                   NaN
# min                     NaN                      NaN                   NaN
# 25%                     NaN                      NaN                   NaN
# 50%                     NaN                      NaN                   NaN
# 75%                     NaN                      NaN                   NaN
# max                     NaN                      NaN                   NaN
#
#        ImportantHiringEducation  ImportantHiringRep  \
# count                     10883               10878
# unique                        5                   5
# top          Somewhat important  Not very important
# freq                       4204                4211
# mean                        NaN                 NaN
# std                         NaN                 NaN
# min                         NaN                 NaN
# 25%                         NaN                 NaN
# 50%                         NaN                 NaN
# 75%                         NaN                 NaN
# max                         NaN                 NaN
#
#        ImportantHiringGettingThingsDone          Currency            Overpaid  \
# count                             10849              8032                5184
# unique                                5                17                   5
# top                           Important  U.S. dollars ($)  Somewhat underpaid
# freq                               4878              2701                2346
# mean                                NaN               NaN                 NaN
# std                                 NaN               NaN                 NaN
# min                                 NaN               NaN                 NaN
# 25%                                 NaN               NaN                 NaN
# 50%                                 NaN               NaN                 NaN
# 75%                                 NaN               NaN                 NaN
# max                                 NaN               NaN                 NaN
#
#        TabsSpaces  EducationImportant EducationTypes  \
# count       14305                9065          11465
# unique          3                   5            367
# top        Spaces  Somewhat important    Self-taught
# freq         5877                2453           1380
# mean          NaN                 NaN            NaN
# std           NaN                 NaN            NaN
# min           NaN                 NaN            NaN
# 25%           NaN                 NaN            NaN
# 50%           NaN                 NaN            NaN
# 75%           NaN                 NaN            NaN
# max           NaN                 NaN            NaN
#
#                                           SelfTaughtTypes  \
# count                                               10173
# unique                                                791
# top     Official documentation; Trade book; Stack Over...
# freq                                                  437
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                         TimeAfterBootcamp  \
# count                                                 882
# unique                                                  9
# top     I already had a job as a developer when I star...
# freq                                                  423
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           CousinEducation WorkStart  \
# count                                                6906     13523
# unique                                                601        24
# top     Take online courses; Buy books and work throug...   9:00 AM
# freq                                                  192      3570
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#          HaveWorkedLanguage WantWorkLanguage HaveWorkedFramework  \
# count                 13526            12523                7294
# unique                 3909             5059                 202
# top     C#; JavaScript; SQL       JavaScript           .NET Core
# freq                    514              233                1089
# mean                    NaN              NaN                 NaN
# std                     NaN              NaN                 NaN
# min                     NaN              NaN                 NaN
# 25%                     NaN              NaN                 NaN
# 50%                     NaN              NaN                 NaN
# 75%                     NaN              NaN                 NaN
# max                     NaN              NaN                 NaN
#
#        WantWorkFramework HaveWorkedDatabase WantWorkDatabase  \
# count               8499              10792             9159
# unique               322                205              222
# top            .NET Core         SQL Server       SQL Server
# freq                 798               1559              792
# mean                 NaN                NaN              NaN
# std                  NaN                NaN              NaN
# min                  NaN                NaN              NaN
# 25%                  NaN                NaN              NaN
# 50%                  NaN                NaN              NaN
# 75%                  NaN                NaN              NaN
# max                  NaN                NaN              NaN
#
#        HaveWorkedPlatform           WantWorkPlatform  \
# count               10580                      10158
# unique               1099                       1249
# top       Windows Desktop  Amazon Web Services (AWS)
# freq                 1243                        688
# mean                  NaN                        NaN
# std                   NaN                        NaN
# min                   NaN                        NaN
# 25%                   NaN                        NaN
# 50%                   NaN                        NaN
# 75%                   NaN                        NaN
# max                   NaN                        NaN
#
#                              IDE AuditoryEnvironment   Methodology  \
# count                      13197               13451          9587
# unique                      2490                   6           536
# top     Notepad++; Visual Studio  Turn on some music  Agile; Scrum
# freq                         610                7956           905
# mean                         NaN                 NaN           NaN
# std                          NaN                 NaN           NaN
# min                          NaN                 NaN           NaN
# 25%                          NaN                 NaN           NaN
# 50%                          NaN                 NaN           NaN
# 75%                          NaN                 NaN           NaN
# max                          NaN                 NaN           NaN
#
#        VersionControl           CheckInCode          ShipIt OtherPeoplesCode  \
# count           11571                 11204           11209            11202
# unique             10                     6               5                5
# top               Git  Multiple times a day  Somewhat agree   Somewhat agree
# freq             8235                  6164            3827             4507
# mean              NaN                   NaN             NaN              NaN
# std               NaN                   NaN             NaN              NaN
# min               NaN                   NaN             NaN              NaN
# 25%               NaN                   NaN             NaN              NaN
# 50%               NaN                   NaN             NaN              NaN
# 75%               NaN                   NaN             NaN              NaN
# max               NaN                   NaN             NaN              NaN
#
#        ProjectManagement  EnjoyDebugging InTheZone DifficultCommunication  \
# count              11122           11258     11101                  11210
# unique                 5               5         5                      5
# top             Disagree  Somewhat agree     Agree               Disagree
# freq                4844            3918      4741                   5814
# mean                 NaN             NaN       NaN                    NaN
# std                  NaN             NaN       NaN                    NaN
# min                  NaN             NaN       NaN                    NaN
# 25%                  NaN             NaN       NaN                    NaN
# 50%                  NaN             NaN       NaN                    NaN
# 75%                  NaN             NaN       NaN                    NaN
# max                  NaN             NaN       NaN                    NaN
#
#        CollaborateRemote                              MetricAssess  \
# count              11130                                      9625
# unique                 5                                      1445
# top       Somewhat agree  Customer satisfaction; On time/in budget
# freq                3404                                       360
# mean                 NaN                                       NaN
# std                  NaN                                       NaN
# min                  NaN                                       NaN
# 25%                  NaN                                       NaN
# 50%                  NaN                                       NaN
# 75%                  NaN                                       NaN
# max                  NaN                                       NaN
#
#        EquipmentSatisfiedMonitors EquipmentSatisfiedCPU EquipmentSatisfiedRAM  \
# count                       11130                 11127                 11133
# unique                          5                     5                     5
# top                     Satisfied             Satisfied             Satisfied
# freq                         4344                  4582                  4469
# mean                          NaN                   NaN                   NaN
# std                           NaN                   NaN                   NaN
# min                           NaN                   NaN                   NaN
# 25%                           NaN                   NaN                   NaN
# 50%                           NaN                   NaN                   NaN
# 75%                           NaN                   NaN                   NaN
# max                           NaN                   NaN                   NaN
#
#        EquipmentSatisfiedStorage EquipmentSatisfiedRW InfluenceInternet  \
# count                      11100                11110             11106
# unique                         5                    5                 5
# top                    Satisfied            Satisfied         Satisfied
# freq                        4558                 4633              4166
# mean                         NaN                  NaN               NaN
# std                          NaN                  NaN               NaN
# min                          NaN                  NaN               NaN
# 25%                          NaN                  NaN               NaN
# 50%                          NaN                  NaN               NaN
# 75%                          NaN                  NaN               NaN
# max                          NaN                  NaN               NaN
#
#        InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# count                  8262                 8262                 8239
# unique                    5                    5                    5
# top          Some influence  No influence at all  No influence at all
# freq                   2269                 4174                 3923
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#          InfluenceTechStack InfluenceDeptTech    InfluenceVizTools  \
# count                  8253              8243                 8244
# unique                    5                 5                    5
# top     No influence at all    Some influence  No influence at all
# freq                   3068              2291                 3833
# mean                    NaN               NaN                  NaN
# std                     NaN               NaN                  NaN
# min                     NaN               NaN                  NaN
# 25%                     NaN               NaN                  NaN
# 50%                     NaN               NaN                  NaN
# 75%                     NaN               NaN                  NaN
# max                     NaN               NaN                  NaN
#
#           InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# count                  8255                 8243                 8229
# unique                    5                    5                    5
# top     No influence at all  No influence at all  No influence at all
# freq                   3127                 3550                 4572
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#        InfluenceRecruitment InfluenceCommunication  \
# count                  8244                   8250
# unique                    5                      5
# top     No influence at all    No influence at all
# freq                   4950                   2554
# mean                    NaN                    NaN
# std                     NaN                    NaN
# min                     NaN                    NaN
# 25%                     NaN                    NaN
# 50%                     NaN                    NaN
# 75%                     NaN                    NaN
# max                     NaN                    NaN
#
#                                    StackOverflowDescribes  \
# count                                               13556
# unique                                                  5
# top     I have a login for Stack Overflow, but haven't...
# freq                                                 6994
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         StackOverflowSatisfaction StackOverflowDevices  \
# count                13452.000000                12946
# unique                        NaN                   37
# top                           NaN              Desktop
# freq                          NaN                 6121
# mean                     8.357865                  NaN
# std                      1.405546                  NaN
# min                      0.000000                  NaN
# 25%                      8.000000                  NaN
# 50%                      8.000000                  NaN
# 75%                      9.000000                  NaN
# max                     10.000000                  NaN
#
#        StackOverflowFoundAnswer StackOverflowCopiedCode  \
# count                     12691                   12577
# unique                        5                       5
# top     At least once each week           Once or twice
# freq                       4854                    3944
# mean                        NaN                     NaN
# std                         NaN                     NaN
# min                         NaN                     NaN
# 25%                         NaN                     NaN
# 50%                         NaN                     NaN
# 75%                         NaN                     NaN
# max                         NaN                     NaN
#
#        StackOverflowJobListing StackOverflowCompanyPage  \
# count                    12425                    12411
# unique                       5                        5
# top        Haven't done at all      Haven't done at all
# freq                      7576                     9884
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        StackOverflowJobSearch StackOverflowNewQuestion  StackOverflowAnswer  \
# count                   12407                    12472                12445
# unique                      5                        5                    5
# top       Haven't done at all      Haven't done at all  Haven't done at all
# freq                     9106                     8164                 7356
# mean                      NaN                      NaN                  NaN
# std                       NaN                      NaN                  NaN
# min                       NaN                      NaN                  NaN
# 25%                       NaN                      NaN                  NaN
# 50%                       NaN                      NaN                  NaN
# 75%                       NaN                      NaN                  NaN
# max                       NaN                      NaN                  NaN
#
#        StackOverflowMetaChat StackOverflowAdsRelevant  \
# count                  12414                    11527
# unique                     5                        5
# top      Haven't done at all           Somewhat agree
# freq                   10601                     5082
# mean                     NaN                      NaN
# std                      NaN                      NaN
# min                      NaN                      NaN
# 25%                      NaN                      NaN
# 50%                      NaN                      NaN
# 75%                      NaN                      NaN
# max                      NaN                      NaN
#
#        StackOverflowAdsDistracting StackOverflowModeration  \
# count                        11841                   11336
# unique                           5                       5
# top                       Disagree                Disagree
# freq                          6645                    6730
# mean                           NaN                     NaN
# std                            NaN                     NaN
# min                            NaN                     NaN
# 25%                            NaN                     NaN
# 50%                            NaN                     NaN
# 75%                            NaN                     NaN
# max                            NaN                     NaN
#
#        StackOverflowCommunity StackOverflowHelpful StackOverflowBetter  \
# count                   12064                12542               12462
# unique                      5                    5                   5
# top            Somewhat agree                Agree      Strongly agree
# freq                     3974                 6300                5412
# mean                      NaN                  NaN                 NaN
# std                       NaN                  NaN                 NaN
# min                       NaN                  NaN                 NaN
# 25%                       NaN                  NaN                 NaN
# 50%                       NaN                  NaN                 NaN
# 75%                       NaN                  NaN                 NaN
# max                       NaN                  NaN                 NaN
#
#        StackOverflowWhatDo StackOverflowMakeMoney Gender  \
# count                12385                  11668  12910
# unique                   5                      5     20
# top         Somewhat agree               Disagree   Male
# freq                  3308                   6902  11664
# mean                   NaN                    NaN    NaN
# std                    NaN                    NaN    NaN
# min                    NaN                    NaN    NaN
# 25%                    NaN                    NaN    NaN
# 50%                    NaN                    NaN    NaN
# 75%                    NaN                    NaN    NaN
# max                    NaN                    NaN    NaN
#
#        HighestEducationParents                          Race      SurveyLong  \
# count                    12853                         12218           12803
# unique                      10                            59               5
# top        A bachelor's degree  White or of European descent  Somewhat agree
# freq                      3671                          8954            4140
# mean                       NaN                           NaN             NaN
# std                        NaN                           NaN             NaN
# min                        NaN                           NaN             NaN
# 25%                        NaN                           NaN             NaN
# 50%                        NaN                           NaN             NaN
# 75%                        NaN                           NaN             NaN
# max                        NaN                           NaN             NaN
#
#        QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# count                 12736              12706             12760
# unique                    5                  5                 5
# top                   Agree           Disagree             Agree
# freq                   5753               8017              5482
# mean                    NaN                NaN               NaN
# std                     NaN                NaN               NaN
# min                     NaN                NaN               NaN
# 25%                     NaN                NaN               NaN
# 50%                     NaN                NaN               NaN
# 75%                     NaN                NaN               NaN
# max                     NaN                NaN               NaN
#
#                Salary  ExpectedSalary
# count     5009.000000      818.000000
# unique            NaN             NaN
# top               NaN             NaN
# freq              NaN             NaN
# mean     58341.398571    32231.521687
# std      40753.384986    28543.877274
# min          0.000000        0.000000
# 25%      27956.989247     4716.459735
# 50%      51612.903226    29784.946237
# 75%      83333.333333    50000.000000
# max     195000.000000   120000.000000

# %% [raw]
# Brief summary of what we have seen so far:
# Upon analyzing the dataset, it was discovered that it consists of a Pandas DataFrame with 19,102 entries. The DataFrame comprises 154 columns, with data types including float64 (6 columns), int64 (1 column), and object (147 columns). The memory usage for this DataFrame is reported to be around 22.4+ MB. These findings provide an overview of the dataset's structure and memory requirements.
# Furthermore, by utilizing `df.describe(include='all')`, we gained insights into various aspects of the dataset's columns. This includes the count, unique values, top values, and frequencies for object and categorical data type columns. Additionally, we obtained standard statistical measures such as count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum for numerical columns.

# %%
# How many respondents program as a hobby or contribute to open source projects?

# Set the figure size
plt.figure(figsize=(10,6))

# Create histogram using seaborn
sns.countplot(y='ProgramHobby', data=df)

# Set the title and labels
plt.title('Do you program as a hobby or contribute to open source projects?')
plt.xlabel('Count')
plt.ylabel('Hobby Status')

# Show the plot
plt.show()

# %%
# Create a frequency table
hobby_counts = df['ProgramHobby'].value_counts().reset_index()
hobby_counts.columns = ['Hobby Status', 'Count']

# Display the frequency table
print(hobby_counts)
# Out:
#                                 Hobby Status  Count
# 0                  Yes, I program as a hobby   9260
# 1                                  Yes, both   5033
# 2                                         No   3661
# 3  Yes, I contribute to open source projects   1148

# %%
# Business Question: What is the distribution of programming hobbies in the top 10 countries with the most respondents?

# Set the figure size
plt.figure(figsize=(15,10))

# Create count plot with seaborn
sns.countplot(y='Country', hue='ProgramHobby', data=df, order=df.Country.value_counts().iloc[:10].index)

# Set the title and labels
plt.title('Programming Hobby Distribution by Country (Top 10 Countries)')
plt.xlabel('Count')
plt.ylabel('Country')

# Display the legend
plt.legend(title='ProgramHobby', title_fontsize='13', loc='lower right')

# Show the plot
plt.show()

# %%
# Filter the DataFrame to include only the top 10 countries with the most respondents
top_10_countries = df['Country'].value_counts().nlargest(10).index
filtered_df = df[df['Country'].isin(top_10_countries)]

# Create a pivot table to count the number of respondents for each programming hobby in each country
pivot_table = pd.pivot_table(filtered_df, index='Country', columns='ProgramHobby', aggfunc='size', fill_value=0)

# Display the pivot table
print(pivot_table)
# Out:
# ProgramHobby     No  Yes, I contribute to open source projects  \
# Country
# Australia        68                                         28
# Canada          172                                         38
# France          101                                         42
# Germany         212                                         89
# India           321                                        112
# Israel          100                                         26
# Netherlands      49                                         23
# Poland          108                                         26
# United Kingdom  277                                         64
# United States   810                                        200
#
# ProgramHobby    Yes, I program as a hobby  Yes, both
# Country
# Australia                             199        104
# Canada                                475        189
# France                                237        142
# Germany                               652        384
# India                                 653        471
# Israel                                131         81
# Netherlands                           176        125
# Poland                                386        174
# United Kingdom                        741        342
# United States                        2151       1203

# %% [raw]
# Code Nation Chronicles: Unraveling the Developer's Universe
# (C.) How many respondents program as a hobby or contribute to open source projects?
# (D.) What is the distribution of programming hobbies in the top 10 countries with the most respondents?
# (E.) How is the distribution of programming experience among the survey respondents?
#
# Programming Hobby or Open Source Contribution?
# From the survey data, it is evident that a substantial number of respondents have a passion for programming or contribute to open source projects. Out of the total respondents, 9,260 individuals indicated that they program as a hobby, while an impressive 1,148 respondents actively contribute to open source projects without engaging in programming as a hobby. Additionally, a significant portion of respondents (5,033) enjoy both programming as a hobby and contributing to open source projects, showcasing their enthusiasm and dedication to the tech community.
#
# The Top 10 Countries: A Global Perspective
# Focusing on the top 10 countries with the most survey respondents, we gain insights into the distribution of programming hobbies within these tech-driven nations. The United States emerges as the leader, with a staggering 2,151 respondents engaging in programming as a hobby. Close behind, Germany boasts 652 hobbyist programmers, highlighting its thriving tech culture. India, a rapidly growing tech hub, showcases its enthusiasm for coding with 653 hobbyist programmers and 471 individuals contributing to open source projects.
#
# The Power of Hobbies and Contributions
# Beyond pure hobbyist interests, the data reveals the impact of open source contributions across different countries. The United Kingdom stands out with 64 respondents actively contributing to open source projects, followed by India (112) and Germany (89). These numbers demonstrate the global collaborative efforts of developers contributing to open source projects, which drive technological advancements and foster community growth.

# %%
print(df['YearsProgram'].unique())
# Out:
# ['2 to 3 years' '9 to 10 years' '20 or more years' '14 to 15 years'
#  '6 to 7 years' '10 to 11 years' '13 to 14 years' '12 to 13 years'
#  '15 to 16 years' '11 to 12 years' '8 to 9 years' '5 to 6 years'
#  '18 to 19 years' '7 to 8 years' '1 to 2 years' '3 to 4 years'
#  'Less than a year' '4 to 5 years' '17 to 18 years' '16 to 17 years'
#  '19 to 20 years' nan]

# %%
# Business Question: How is the distribution of programming experience among the survey respondents?

# Define the order
ordered_categories = ['Less than a year', '1 to 2 years', '2 to 3 years', '3 to 4 years', '4 to 5 years',
                      '5 to 6 years', '6 to 7 years', '7 to 8 years', '8 to 9 years', '9 to 10 years',
                      '10 to 11 years', '11 to 12 years', '12 to 13 years', '13 to 14 years', '14 to 15 years',
                      '15 to 16 years', '16 to 17 years', '17 to 18 years', '18 to 19 years', '19 to 20 years',
                      '20 or more years']

# Convert YearsProgram column to ordered categorical type
df['YearsProgram'] = pd.Categorical(df['YearsProgram'], categories=ordered_categories, ordered=True)

# Get the frequency of each category
years_program_freq = df['YearsProgram'].value_counts().sort_index()

# Plot the result
plt.figure(figsize=(10,6))
years_program_freq.plot(kind='bar')
plt.title('Years of Programming Experience Distribution')
plt.xlabel('Years of Programming')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [raw]
# The largest group of respondents has been programming for "20 or more years" with a frequency of 3,471. This suggests a significant presence of very experienced programmers in the dataset.
#
# The frequencies for "1 to 2 years" up to "5 to 6 years" show an increasing trend, indicating that many respondents are in the early to mid-stages of their programming career. The highest frequency in this range is for "4 to 5 years" with 1,364 respondents.
#
# After the "5 to 6 years" category, the frequencies generally decrease, suggesting fewer respondents with 6 or more but less than 20 years of programming experience. However, there's a notable increase at the "9 to 10 years" category, which might indicate a group of programmers who stayed in the field for a significant amount of time.
#
# The smallest group of respondents has been programming for "18 to 19 years" with a frequency of 236.
#
# For people with less than a year of programming experience, there were 455 respondents, which is higher than those with 18-19 years of experience but much lower than those in the early to mid-stages of their career (1 to 6 years).
#
# In summary, the data suggests a distribution where a significant portion of respondents are either in the early to mid stages of their programming career (1 to 6 years) or have very high programming experience (20 or more years). The frequencies are generally lower for intermediate levels of experience (7 to 19 years), with some fluctuations.

# %%
# Get unique responses in the 'FormalEducation' column
formal_education_unique_responses = df['FormalEducation'].unique()
print('Unique responses for FormalEducation:\n', formal_education_unique_responses)

# Get unique responses in the 'MajorUndergrad' column
major_undergrad_unique_responses = df['MajorUndergrad'].unique()
print('\nUnique responses for MajorUndergrad:\n', major_undergrad_unique_responses)
# Out:
# Unique responses for FormalEducation:
#  ['Secondary school'
#  "Some college/university study without earning a bachelor's degree"
#  "Bachelor's degree" 'Doctoral degree' "Master's degree"
#  'Professional degree' 'Primary/elementary school'
#  'I prefer not to answer' 'I never completed any formal education']
#
# Unique responses for MajorUndergrad:
#  [nan 'Computer science or software engineering'
#  'A non-computer-focused engineering discipline' 'A social science'
#  'Mathematics or statistics'
#  'Computer engineering or electrical/electronics engineering'
#  'A natural science' 'A business discipline'
#  'Computer programming or Web development'
#  'Information technology, networking, or system administration'
#  'I never declared a major' 'Something else'
#  'Fine arts or performing arts' 'Management information systems'
#  'A humanities discipline' 'Psychology' 'A health science']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get normalized value counts for FormalEducation
formal_education_counts = df['FormalEducation'].value_counts(normalize=True).sort_values(ascending=True)

# Plot the result
plt.figure(figsize=(10,6))
formal_education_counts.mul(100).plot(kind='barh', color='blue')
plt.title('Distribution of Formal Education')
plt.xlabel('Percentage of Respondents (%)')
plt.ylabel('Formal Education')
plt.grid(axis='x')
plt.show()

# Get normalized value counts for MajorUndergrad
major_undergrad_counts = df['MajorUndergrad'].value_counts(normalize=True).sort_values(ascending=True)

# Plot the result
plt.figure(figsize=(10,6))
major_undergrad_counts.mul(100).plot(kind='barh', color='orange')
plt.title('Distribution of Undergraduate Majors')
plt.xlabel('Percentage of Respondents (%)')
plt.ylabel('Undergraduate Major')
plt.grid(axis='x')
plt.show()

# %%
# For 'FormalEducation'
formal_edu_freq = df['FormalEducation'].value_counts().sort_values(ascending=False)
formal_edu_percentage = (df['FormalEducation'].value_counts(normalize=True) * 100).sort_values(ascending=False)

# Creating a dataframe for better visualization
formal_edu_df = pd.DataFrame({'Frequency': formal_edu_freq, 'Percentage': formal_edu_percentage})
print("Formal Education:")
print(formal_edu_df)
print("\n")

# For 'MajorUndergrad'
major_undergrad_freq = df['MajorUndergrad'].value_counts().sort_values(ascending=False)
major_undergrad_percentage = (df['MajorUndergrad'].value_counts(normalize=True) * 100).sort_values(ascending=False)

# Creating a dataframe for better visualization
major_undergrad_df = pd.DataFrame({'Frequency': major_undergrad_freq, 'Percentage': major_undergrad_percentage})
print("Major Undergrad:")
print(major_undergrad_df)
# Out:
# Formal Education:
#                                                     Frequency  Percentage
# FormalEducation
# Bachelor's degree                                        8099   42.398702
# Master's degree                                          4143   21.688828
# Some college/university study without earning a...       2869   15.019370
# Secondary school                                         2227   11.658465
# Doctoral degree                                           551    2.884515
# I prefer not to answer                                    409    2.141137
# Primary/elementary school                                 404    2.114962
# Professional degree                                       255    1.334939
# I never completed any formal education                    145    0.759083
#
#
# Major Undergrad:
#                                                     Frequency  Percentage
# MajorUndergrad
# Computer science or software engineering                 8098   50.934021
# Computer engineering or electrical/electronics ...       1645   10.346563
# Computer programming or Web development                  1311    8.245802
# Information technology, networking, or system a...        754    4.742437
# A natural science                                         701    4.409082
# Mathematics or statistics                                 667    4.195232
# A non-computer-focused engineering discipline             652    4.100887
# A business discipline                                     341    2.144789
# Something else                                            333    2.094471
# A humanities discipline                                   323    2.031574
# Management information systems                            257    1.616454
# Fine arts or performing arts                              229    1.440342
# A social science                                          228    1.434052
# I never declared a major                                  222    1.396314
# Psychology                                                 80    0.503176
# A health science                                           58    0.364803

# %% [raw]
# Education and Skill Development: The Birth of a Developer
# We will investigate the sources of knowledge and skill acquisition among developers, their educational backgrounds, and their pathways into the field.
# (A.) Where do most developers acquire their skills and knowledge?
# (B.) What educational background do they come from?
#
# When it comes to formal education, it's evident that our respondent pool is highly educated. In fact, the majority of respondents hold either a Bachelor's (42.40%) or a Master's degree (21.69%), pointing towards a significant level of formal training in their respective fields.
#
# Furthermore, a notable 15.02% of respondents have some college or university education but didn't earn a bachelor's degree. These individuals could represent a group of self-learners who might have decided to dive into their careers early or those who have pursued alternative forms of education, like coding bootcamps. At the same time, about 11.66% of respondents only completed secondary school, implying that they might have directly stepped into the professional world or pursued non-traditional forms of education.
#
# At the other end of the spectrum, 2.88% of respondents hold a Doctoral degree, denoting a small but significant group of highly specialized individuals, while only 0.76% reported not having completed any formal education, showcasing the importance of formal education in this field.
#
# Turning our attention to undergraduate majors, there is a strong leaning towards computer-centric disciplines. A whopping 50.93% of respondents studied Computer Science or Software Engineering, which is expected given the survey's audience. Add in the 10.35% who studied Computer Engineering or Electrical/Electronics Engineering, and the 8.25% who majored in Computer Programming or Web Development, and we have almost 70% of respondents with a computer-focused undergraduate major.
#
# Further demonstrating the versatility of the tech industry, we have respondents from diverse academic backgrounds like Natural Sciences (4.41%), Mathematics or Statistics (4.20%), Non-Computer-Focused Engineering disciplines (4.10%), and even Business disciplines (2.14%). Notably, there's a small but intriguing group (2.03%) who majored in Humanities, suggesting that tech is indeed a field that invites a wide range of academic backgrounds.
#
# In a nutshell, these insights paint a picture of a highly educated group of tech professionals with diverse academic backgrounds, with a significant tilt towards computer-centric education.

# %%
# Split the 'EducationTypes' and 'SelfTaughtTypes' columns on the semicolon (;) as it seems to be the separator between different types of education/self-taught methods
edu_types = df['EducationTypes'].str.split(';', expand=True).stack().value_counts(normalize=True).sort_values(ascending=True)
self_taught_types = df['SelfTaughtTypes'].str.split(';', expand=True).stack().value_counts(normalize=True).sort_values(ascending=True)

# Plot the results for 'EducationTypes'
plt.figure(figsize=(10,6))
edu_types.mul(100).plot(kind='barh', color='blue')
plt.title('Distribution of Education Types')
plt.xlabel('Percentage of Respondents (%)')
plt.ylabel('Education Types')
plt.grid(axis='x')
plt.show()

# Plot the results for 'SelfTaughtTypes'
plt.figure(figsize=(10,6))
self_taught_types.mul(100).plot(kind='barh', color='orange')
plt.title('Distribution of Self-Taught Types')
plt.xlabel('Percentage of Respondents (%)')
plt.ylabel('Self-Taught Types')
plt.grid(axis='x')
plt.show()

# For 'EducationTypes' frequency and percentage
edu_types_freq = df['EducationTypes'].str.split(';', expand=True).stack().value_counts().sort_values(ascending=False)
edu_types_percentage = (df['EducationTypes'].str.split(';', expand=True).stack().value_counts(normalize=True) * 100).sort_values(ascending=False)

# Creating a dataframe for better visualization
edu_types_df = pd.DataFrame({'Frequency': edu_types_freq, 'Percentage': edu_types_percentage})
print("Education Types:")
print(edu_types_df)
print("\n")

# For 'SelfTaughtTypes' frequency and percentage
self_taught_types_freq = df['SelfTaughtTypes'].str.split(';', expand=True).stack().value_counts().sort_values(ascending=False)
self_taught_types_percentage = (df['SelfTaughtTypes'].str.split(';', expand=True).stack().value_counts(normalize=True) * 100).sort_values(ascending=False)

# Creating a dataframe for better visualization
self_taught_types_df = pd.DataFrame({'Frequency': self_taught_types_freq, 'Percentage': self_taught_types_percentage})
print("Self-Taught Types:")
print(self_taught_types_df)
# Out:
# Education Types:
#                             Frequency  Percentage
#  Self-taught                     7403   21.805596
# Online course                    5047   14.865979
#  Open source contributions       4390   12.930781
#  On-the-job training             3004    8.848306
# Self-taught                      3000    8.836524
#  Hackathon                       2686    7.911635
#  Coding competition              2377    7.001473
# On-the-job training              1691    4.980854
#  Industry certification          1060    3.122239
#  Part-time/evening course        1002    2.951399
# Industry certification            626    1.843888
# Part-time/evening course          577    1.699558
#  Bootcamp                         563    1.658321
# Bootcamp                          356    1.048601
# Open source contributions          75    0.220913
# Coding competition                 51    0.150221
# Hackathon                          42    0.123711
#
#
# Self-Taught Types:
#                                Frequency  Percentage
# Official documentation              8310   20.059382
#  Stack Overflow Q&A                 7635   18.430009
#  Non-Stack online communities       4965   11.984937
#  Built-in help                      4884   11.789413
#  Trade book                         4452   10.746615
#  Stack Overflow Docs                2510    6.058851
#  Friends network                    1942    4.687764
#  Textbook                           1831    4.419823
#  Company internal community         1694    4.089121
#  Other                               992    2.394574
# Trade book                           986    2.380090
# Stack Overflow Q&A                   493    1.190045
#  Tutoring/mentoring                  349    0.842446
# Textbook                             152    0.366910
# Non-Stack online communities          74    0.178627
# Other                                 58    0.140005
# Stack Overflow Docs                   53    0.127936
# Friends network                       16    0.038622
# Company internal community            14    0.033794
# Built-in help                         13    0.031381
# Tutoring/mentoring                     4    0.009656

# %% [raw]
# In terms of acquiring technical skills, developers love to learn! They have varied approaches and lean heavily on self-study to grow their knowledge base. For instance, "self-taught" methods, which includes anything from reading programming books to tinkering with personal projects, hold the lead with over 21.8% of developers endorsing it. Following closely behind is the trend of online courses, which grabbed the attention of nearly 15% of developers. Contributing to open-source projects and on-the-job training are also favored education types, indicating that practical experience is highly valued in the field.
#
# Among the self-taught types, developers overwhelmingly turn to "official documentation," with over 20% of them referring to these materials. Not far behind is "Stack Overflow Q&A," a staple for many developers dealing with tricky bugs or complicated algorithms, accounting for 18.4% of the preferred methods. Other noteworthy resources include "Non-Stack online communities" and "built-in help," hinting at the significance of community support and well-documented tools in the developers' learning journey.
#
# However, traditional resources like "trade books" and "textbooks" haven't been entirely abandoned. They make a noticeable appearance on the list, reminding us that despite the shift towards digital and self-guided learning, some developers still value the structured knowledge these resources provide.
#
# Taken together, the data suggest a vibrant, continuously learning, and resourceful community of developers who are not just passive consumers of knowledge but active participants in creating and sharing it. Whether they're contributing to open-source projects or answering queries on Stack Overflow, it's clear that developers play an integral role in the larger ecosystem of learning and knowledge production.

# %% [raw]
# Technology and Tools: The Developer's Magic Wand
# Here, we'll discover the most popular programming languages, databases, platforms, and development environments among developers.
# (F.) What programming languages are most popular among developers?
# (G.) What platforms and databases do they primarily work with?
# (H.) Which development environments (IDEs) do they prefer?

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_wordcloud(df, columns):
    # Count occurrences for the pair of columns
    counts = Counter()
    for col in columns:
        # Drop missing values, split lists, and update counts
        df[col].dropna().str.split(';').apply(counts.update)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate_from_frequencies(counts)

    # Plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# Generate word clouds for each pair
generate_wordcloud(df, ['HaveWorkedLanguage', 'WantWorkLanguage'])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_wordcloud(df, columns):
    # Count occurrences for the pair of columns
    counts = Counter()
    for col in columns:
        # Drop missing values, split lists, and update counts
        df[col].dropna().str.split(';').apply(counts.update)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate_from_frequencies(counts)

    # Plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# Generate word clouds for each pair
generate_wordcloud(df, ['HaveWorkedFramework', 'WantWorkFramework'])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_wordcloud(df, columns):
    # Count occurrences for the pair of columns
    counts = Counter()
    for col in columns:
        # Drop missing values, split lists, and update counts
        df[col].dropna().str.split(';').apply(counts.update)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate_from_frequencies(counts)

    # Plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# Generate word clouds for each pair

generate_wordcloud(df, ['HaveWorkedDatabase', 'WantWorkDatabase'])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_wordcloud(df, columns):
    # Count occurrences for the pair of columns
    counts = Counter()
    for col in columns:
        # Drop missing values, split lists, and update counts
        df[col].dropna().str.split(';').apply(counts.update)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate_from_frequencies(counts)

    # Plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# Generate word clouds for each pair

generate_wordcloud(df, ['HaveWorkedPlatform', 'WantWorkPlatform'])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_wordcloud(df, columns):
    # Count occurrences for the pair of columns
    counts = Counter()
    for col in columns:
        # Drop missing values, split lists, and update counts
        df[col].dropna().str.split(';').apply(counts.update)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate_from_frequencies(counts)

    # Plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# Generate word clouds for each pair

generate_wordcloud(df, ['IDE'])

# %%
column_pairs = [
    ("HaveWorkedLanguage", "WantWorkLanguage"),
    ("HaveWorkedFramework", "WantWorkFramework"),
    ("HaveWorkedDatabase", "WantWorkDatabase"),
    ("HaveWorkedPlatform", "WantWorkPlatform"),
]
single_column = ["IDE"]

# define a function to process and print data
def process_columns(df, col1, col2=None):
    # Split the multiple answers, count the occurrences and sort in descending order
    values1 = df[col1].str.split(';').explode().value_counts().sort_values(ascending=False)
    percentage1 = (values1 / df[col1].str.split(';').explode().count() * 100).sort_values(ascending=False)

    # Creating a dataframe for better visualization
    df1 = pd.DataFrame({'Frequency': values1, 'Percentage': percentage1})
    print(f"{col1}:")
    print(df1)
    print("\n")
    
    if col2:
        values2 = df[col2].str.split(';').explode().value_counts().sort_values(ascending=False)
        percentage2 = (values2 / df[col2].str.split(';').explode().count() * 100).sort_values(ascending=False)

        # Creating a dataframe for better visualization
        df2 = pd.DataFrame({'Frequency': values2, 'Percentage': percentage2})
        print(f"{col2}:")
        print(df2)
        print("\n")

# loop over the pairs
for pair in column_pairs:
    process_columns(df, pair[0], pair[1])
    
# loop over the single column
for col in single_column:
    process_columns(df, col)
# Out:
# HaveWorkedLanguage:
#                     Frequency  Percentage
# HaveWorkedLanguage
#  SQL                     6673   13.425749
#  JavaScript              6331   12.737662
#  Python                  3828    7.701748
# C#                       3337    6.713880
#  PHP                     3243    6.524757
#  Java                    2939    5.913124
# Java                     2118    4.261312
# JavaScript               2064    4.152667
# C                        1970    3.963543
#  C++                     1610    3.239241
#  TypeScript              1380    2.776492
#  C#                      1318    2.651751
# C++                      1242    2.498843
#  Ruby                    1165    2.343923
#  Swift                    801    1.611573
#  VB.NET                   712    1.432509
#  Objective-C              708    1.424461
# Assembly                  612    1.231314
#  R                        546    1.098525
#  Matlab                   514    1.034143
#  Perl                     498    1.001952
#  Scala                    494    0.993904
#  C                        485    0.975796
#  VBA                      456    0.917450
#  Go                       372    0.748446
# Python                    371    0.746434
#  Lua                      337    0.678027
#  Visual Basic 6           327    0.657908
# CoffeeScript              262    0.527131
# Groovy                    237    0.476832
# Go                        230    0.462749
#  Groovy                   204    0.410438
#  Haskell                  188    0.378247
# PHP                       187    0.376235
#  F#                       175    0.352091
#  Rust                     165    0.331972
#  CoffeeScript             161    0.323924
#  Smalltalk                153    0.307829
# Objective-C               116    0.233386
# SQL                        94    0.189123
#  Erlang                    88    0.177052
#  Common Lisp               87    0.175040
# Clojure                    81    0.162968
# R                          72    0.144860
# Ruby                       71    0.142849
# Elixir                     70    0.140837
#  Elixir                    68    0.136813
#  Clojure                   61    0.122729
# Perl                       56    0.112669
# Smalltalk                  55    0.110657
# Haskell                    54    0.108645
# Matlab                     45    0.090538
#  Julia                     39    0.078466
# Swift                      31    0.062370
#  Dart                      30    0.060359
# Scala                      24    0.048287
#  Hack                      21    0.042251
# Common Lisp                20    0.040239
# Dart                       15    0.030179
# Lua                        14    0.028167
# Erlang                     13    0.026155
# Hack                       13    0.026155
# VBA                        12    0.024143
# Julia                      11    0.022131
# VB.NET                     11    0.022131
# F#                         10    0.020120
# Rust                        3    0.006036
# Visual Basic 6              3    0.006036
# TypeScript                  2    0.004024
#
#
# WantWorkLanguage:
#                   Frequency  Percentage
# WantWorkLanguage
#  JavaScript            4582    9.996727
#  Python                4029    8.790226
#  SQL                   3934    8.582961
# C#                     2676    5.838333
#  TypeScript            2189    4.775826
#  Java                  2076    4.529290
#  PHP                   1615    3.523508
# C++                    1484    3.237700
#  Swift                 1419    3.095887
# Java                   1333    2.908258
#  Ruby                  1304    2.844987
# C                      1295    2.825352
# JavaScript             1277    2.786081
#  Go                    1260    2.748991
#  C++                   1126    2.456638
#  Scala                 1102    2.404276
#  Rust                  1096    2.391186
#  C#                    1068    2.330097
#  R                      911    1.987564
# Go                      901    1.965747
#  F#                     750    1.636304
#  Haskell                696    1.518490
# Assembly                655    1.429039
#  Objective-C            530    1.156322
# Python                  441    0.962147
#  C                      416    0.907603
# Elixir                  339    0.739609
#  Lua                    338    0.737428
#  Erlang                 332    0.724337
#  Perl                   316    0.689429
# Clojure                 303    0.661067
#  Elixir                 297    0.647976
#  Matlab                 287    0.626159
#  VB.NET                 238    0.519254
# Haskell                 222    0.484346
#  Clojure                212    0.462529
#  Groovy                 189    0.412349
# CoffeeScript            180    0.392713
#  Smalltalk              165    0.359987
#  Julia                  161    0.351260
#  CoffeeScript           151    0.329443
# F#                      142    0.309807
#  Common Lisp            133    0.290171
# Groovy                  132    0.287990
# Swift                   117    0.255263
#  VBA                    116    0.253082
#  Dart                   113    0.246536
# PHP                     105    0.229083
# Common Lisp              96    0.209447
#  Hack                    91    0.198538
# Scala                    85    0.185448
# Objective-C              81    0.176721
# Ruby                     78    0.170176
# Erlang                   73    0.159267
# Dart                     71    0.154903
#  Visual Basic 6          70    0.152722
# Rust                     66    0.143995
# Smalltalk                64    0.139631
# R                        60    0.130904
# TypeScript               52    0.113450
# Julia                    46    0.100360
# Perl                     37    0.080724
# SQL                      33    0.071997
# Lua                      26    0.056725
# Hack                     23    0.050180
# Matlab                   21    0.045817
# VB.NET                    5    0.010909
# Visual Basic 6            3    0.006545
# VBA                       1    0.002182
#
#
# HaveWorkedFramework:
#                      Frequency  Percentage
# HaveWorkedFramework
# AngularJS                 3217   24.277413
#  Node.js                  1766   13.327296
# Node.js                   1628   12.285865
#  .NET Core                1265    9.546449
#  React                    1156    8.723870
# .NET Core                 1089    8.218248
#  Cordova                   621    4.686439
#  Firebase                  439    3.312958
# React                      396    2.988454
#  Xamarin                   331    2.497925
# Xamarin                    275    2.075315
# Hadoop                     268    2.022489
#  Spark                     258    1.947023
# Firebase                   208    1.569693
# Cordova                    121    0.913139
#  Hadoop                    121    0.913139
# Spark                       92    0.694287
#
#
# WantWorkFramework:
#                    Frequency  Percentage
# WantWorkFramework
# AngularJS               3505   18.291410
#  React                  2476   12.921407
#  Node.js                2371   12.373447
#  .NET Core              2266   11.825488
# Node.js                 1818    9.487527
#  Xamarin                 947    4.942073
#  Firebase                820    4.279303
# React                    814    4.247991
# .NET Core                798    4.164492
#  Spark                   698    3.642626
# Hadoop                   677    3.533034
#  Cordova                 649    3.386912
#  Hadoop                  436    2.275337
# Xamarin                  428    2.233587
# Spark                    233    1.215948
# Firebase                 148    0.772362
# Cordova                   78    0.407056
#
#
# HaveWorkedDatabase:
#                     Frequency  Percentage
# HaveWorkedDatabase
# SQL Server               3243   15.111132
#  MySQL                   2981   13.890313
# MySQL                    2694   12.553003
#  SQLite                  2447   11.402078
#  PostgreSQL              2190   10.204557
# MongoDB                  2073    9.659382
#  Oracle                  1331    6.201948
# Redis                    1001    4.664275
#  SQL Server               932    4.342761
# PostgreSQL                729    3.396859
#  Redis                    670    3.121942
# SQLite                    361    1.682121
# Oracle                    354    1.649504
# Cassandra                 337    1.570290
#  MongoDB                  118    0.549835
#
#
# WantWorkDatabase:
#                   Frequency  Percentage
# WantWorkDatabase
# MongoDB                2839   14.865431
#  PostgreSQL            2265   11.859881
#  MySQL                 2134   11.173945
#  SQLite                1816    9.508849
# SQL Server             1576    8.252173
#  Redis                 1302    6.817468
# MySQL                  1190    6.231019
# Redis                  1168    6.115824
# Cassandra              1100    5.759765
#  SQL Server            1082    5.665515
# PostgreSQL              864    4.524034
#  Oracle                 792    4.147031
#  MongoDB                548    2.869410
# SQLite                  263    1.377108
# Oracle                  159    0.832548
#
#
# HaveWorkedPlatform:
#                             Frequency  Percentage
# HaveWorkedPlatform
# Windows Desktop                  2967   12.674071
# Android                          2650   11.319949
#  Amazon Web Services (AWS)       2263    9.666809
#  Linux Desktop                   1876    8.013669
#  Mac OS                          1497    6.394703
# Linux Desktop                    1469    6.275096
#  Raspberry Pi                    1306    5.578812
#  Windows Desktop                 1228    5.245622
#  WordPress                       1066    4.553610
#  Microsoft Azure                 1024    4.374199
#  iOS                              872    3.724904
# Amazon Web Services (AWS)         783    3.344724
# iOS                               777    3.319094
#  Arduino                          775    3.310551
# Mac OS                            476    2.033319
# WordPress                         343    1.465186
#  SharePoint                       268    1.144810
# Microsoft Azure                   261    1.114908
# Raspberry Pi                      217    0.926954
#  Windows Phone                    208    0.888509
#  Serverless                       174    0.743272
# Windows Phone                     173    0.739000
#  Salesforce                       168    0.717642
# Arduino                           148    0.632208
# SharePoint                        109    0.465613
#  Mainframe                        105    0.448526
# Salesforce                         87    0.371636
# Serverless                         81    0.346006
# Mainframe                          39    0.166595
#
#
# WantWorkPlatform:
#                             Frequency  Percentage
# WantWorkPlatform
# Android                          3621   13.749241
#  Amazon Web Services (AWS)       3097   11.759569
#  Raspberry Pi                    2313    8.782655
#  Linux Desktop                   1816    6.895504
#  Mac OS                          1511    5.737394
#  Microsoft Azure                 1499    5.691829
#  iOS                             1460    5.543742
# Linux Desktop                    1410    5.353888
# Windows Desktop                  1359    5.160237
#  Windows Desktop                 1338    5.080498
#  Arduino                         1250    4.746355
# iOS                               977    3.709751
# Amazon Web Services (AWS)         819    3.109812
#  WordPress                        596    2.263062
#  Serverless                       519    1.970687
# Raspberry Pi                      412    1.564399
# Mac OS                            388    1.473269
#  Windows Phone                    340    1.291009
# Arduino                           276    1.047995
# Microsoft Azure                   260    0.987242
# Serverless                        250    0.949271
#  SharePoint                       181    0.687272
# Windows Phone                     165    0.626519
#  Salesforce                       156    0.592345
# WordPress                         118    0.448056
#  Mainframe                        102    0.387303
# Salesforce                         52    0.197448
# SharePoint                         33    0.125304
# Mainframe                          18    0.068348
#
#
# IDE:
#                      Frequency  Percentage
# IDE
#  Visual Studio            4059   11.239097
# Notepad++                 3663   10.142600
#  Visual Studio Code       2584    7.154922
#  IntelliJ                 2439    6.753427
# Atom                      2373    6.570677
#  Vim                      2283    6.321473
#  Eclipse                  2220    6.147030
# Sublime Text              2091    5.789838
#  Android Studio           1526    4.225391
# Vim                       1456    4.031566
#  Sublime Text             1414    3.915271
#  Xcode                    1219    3.375329
#  PyCharm                  1124    3.112280
# Visual Studio             1002    2.774470
#  PHPStorm                  871    2.411740
#  NetBeans                  823    2.278832
#  Notepad++                 742    2.054548
# Emacs                      690    1.910563
#  IPython / Jupyter         678    1.877336
# Android Studio             403    1.115880
# Eclipse                    400    1.107573
# IntelliJ                   347    0.960820
#  RStudio                   338    0.935899
#  RubyMine                  219    0.606396
# PHPStorm                   124    0.343348
#  TextMate                  121    0.335041
# Xcode                      116    0.321196
# Visual Studio Code         107    0.296276
#  Emacs                      99    0.274124
# NetBeans                    83    0.229821
# PyCharm                     81    0.224284
#  Komodo                     70    0.193825
# TextMate                    67    0.185518
# Coda                        56    0.155060
# IPython / Jupyter           55    0.152291
# RStudio                     52    0.143984
#  Zend                       40    0.110757
#  Coda                       26    0.071992
#  Light Table                23    0.063685
# RubyMine                    14    0.038765
# Komodo                      11    0.030458
# Zend                         4    0.011076
# Light Table                  2    0.005538

# %% [raw]
# Technology and Tools: The Developer's Magic Wand
# Here, we'll discover the most popular programming languages, databases, platforms, and development environments among developers.
# (F.) What programming languages are most popular among developers?
# (G.) What platforms and databases do they primarily work with?
# (H.) Which development environments (IDEs) do they prefer?
#
#
# The exploration of developer language preferences reveals a fascinating landscape of choice and competition.
#
# The once undeniable reign of SQL and JavaScript has come under siege, with a combined presence of around 26% of developers having used them. Their popularity, however, is facing competition from rising stars. Python, one of the most beloved languages for its simplicity and wide range of applications, clocks in at 7.7%, while C# takes about 6.7% of the developer workforce.
#
# These languages are followed by PHP and Java with respective percentages of 6.5% and 5.9%, and then comes the second echelon of languages - those with more niche applications or newer arrivals on the scene. They consist of C++, TypeScript, Ruby, Swift, and many others. Each of these holds their own with between 1% and 4% of developers using them.
#
# When it comes to aspirations, JavaScript still leads the pack, but Python inches closer, indicating a possible shift in the coming years. SQL remains a desirable skill, while the interest in TypeScript and C# solidifies their positions.
#
# The analysis of framework preferences showcases the dominion of AngularJS, which captures the attention of almost 25% of developers. Node.js and .NET Core follow with 13% and 9.5% respectively. A similar pattern emerges for future aspirations as AngularJS, React, and Node.js continue to be the go-to frameworks for many developers.
#
# Database technologies seem to follow a more conservative approach. SQL Server and MySQL are the two most popular options, both in current use and desired skills. The NoSQL contender MongoDB shows a significant presence as well, hinting at an ongoing trend of diversification in data management strategies.
#
# Finally, a glance at platform preferences reveals the enduring popularity of Windows and Android. Nonetheless, developers also express a keen interest in expanding their skills in Amazon Web Services, further emphasizing the importance of cloud-based platforms in the tech industry.
#
# It is important to note that the percentages do not add up to 100. This is because respondents could give more than one answer to the questions, highlighting the multi-disciplinary nature of software development. A developer may be using JavaScript for front-end, Python for back-end, and SQL for managing databases, painting a vivid picture of today's polyglot developer.

# %% [raw]
# 3. Work Environment and Preferences: The Developer's Shire
#    We aim to gain insights into the typical working environments of developers, including the size and type of organizations they work for, their work hours, job
#    satisfaction, and remote work frequency.
#    (F.) What is the size and type of organizations developes work for?
#    (G.) What are their working hours and job satisfaction levels?
#    (H.) How often do they work remotely?

# %%
company_type_freq = df['CompanyType'].value_counts().sort_values(ascending=False)
company_type_percentage = (df['CompanyType'].value_counts(normalize=True) * 100).sort_values(ascending=False)

company_type_unique_responses = df['CompanyType'].unique()
print('\nUnique responses for CompanyType:\n', company_type_unique_responses)
# Out:
# Unique responses for CompanyType:
#  [nan 'Privately-held limited company, not in startup mode'
#  'Publicly-traded corporation'
#  'Non-profit/non-governmental organization or private school/university'
#  'Government agency or public school/university' 'Pre-series A startup'
#  'Venture-funded startup' "I don't know"
#  'Sole proprietorship or partnership, not in startup mode'
#  'I prefer not to answer' 'State-owned company' 'Something else']

# %%
# Set display options to show the full contents of cells
pd.set_option('display.max_colwidth', None)

# Calculate the counts of each category
company_type_counts = df['CompanyType'].value_counts()

# Calculate percentages
total = company_type_counts.sum()
percentages = company_type_counts.apply(lambda x: round(100 * x / total, 2))

# Create a DataFrame for better visualization
company_type_table = pd.DataFrame({'Frequency': company_type_counts, 'Percentage': percentages})

# Sort the table by frequency in descending order
company_type_table = company_type_table.sort_values(by='Frequency', ascending=False)

# Print the table
print(company_type_table)
# Out:
#                                                                        Frequency  \
# CompanyType
# Privately-held limited company, not in startup mode                         6283
# Publicly-traded corporation                                                 2241
# I don't know                                                                1178
# Sole proprietorship or partnership, not in startup mode                     1127
# Venture-funded startup                                                       958
# Government agency or public school/university                                923
# I prefer not to answer                                                       602
# Pre-series A startup                                                         485
# Non-profit/non-governmental organization or private school/university        453
# State-owned company                                                          230
# Something else                                                               129
#
#                                                                        Percentage
# CompanyType
# Privately-held limited company, not in startup mode                         43.01
# Publicly-traded corporation                                                 15.34
# I don't know                                                                 8.06
# Sole proprietorship or partnership, not in startup mode                      7.71
# Venture-funded startup                                                       6.56
# Government agency or public school/university                                6.32
# I prefer not to answer                                                       4.12
# Pre-series A startup                                                         3.32
# Non-profit/non-governmental organization or private school/university        3.10
# State-owned company                                                          1.57
# Something else                                                               0.88

# %%
company_size_freq = df['CompanySize'].value_counts().sort_values(ascending=False)
company_size_percentage = (df['CompanySize'].value_counts(normalize=True) * 100).sort_values(ascending=False)

company_size_unique_responses = df['CompanySize'].unique()
print('\nUnique responses for CompanySize:\n', company_size_unique_responses)
# Out:
# Unique responses for CompanySize:
#  [nan '20 to 99 employees' '10,000 or more employees' '10 to 19 employees'
#  'Fewer than 10 employees' '5,000 to 9,999 employees'
#  '100 to 499 employees' '1,000 to 4,999 employees' '500 to 999 employees'
#  "I don't know" 'I prefer not to answer']

# %%
# Set display options to show the full contents of cells
pd.set_option('display.max_colwidth', None)

# Calculate the counts of each category
company_size_counts = df['CompanySize'].value_counts()

# Calculate percentages
total = company_size_counts.sum()
percentages = company_size_counts.apply(lambda x: round(100 * x / total, 2))

# Create a DataFrame for better visualization
company_size_table = pd.DataFrame({'Frequency': company_size_counts, 'Percentage': percentages})

# Sort the table by frequency in descending order
company_size_table = company_size_table.sort_values(by='Frequency', ascending=False)

# Print the table
print(company_size_table)
# Out:
#                           Frequency  Percentage
# CompanySize
# 20 to 99 employees             3214       21.93
# 100 to 499 employees           2858       19.50
# 10,000 or more employees       1998       13.64
# 10 to 19 employees             1544       10.54
# 1,000 to 4,999 employees       1482       10.11
# Fewer than 10 employees        1456        9.94
# 500 to 999 employees            946        6.46
# 5,000 to 9,999 employees        606        4.14
# I don't know                    311        2.12
# I prefer not to answer          238        1.62

# %%
# Given list in the desired order
time_list = ['1:00 AM', '2:00 AM', '3:00 AM', '4:00 AM', '5:00 AM', '6:00 AM', '7:00 AM', '8:00 AM',
             '9:00 AM', '10:00 AM', '11:00 AM', 'Noon', '1:00 PM', '2:00 PM', '3:00 PM', '4:00 PM',
             '5:00 PM', '6:00 PM', '7:00 PM', '8:00 PM', '9:00 PM', '10:00 PM', '11:00 PM', 'Midnight']

# Create a DataFrame from the list
df = pd.DataFrame({'Time': time_list})

# Print each item in a separate row
for index, row in df.iterrows():
    print(row['Time'])
# Out:
# 1:00 AM
# 2:00 AM
# 3:00 AM
# 4:00 AM
# 5:00 AM
# 6:00 AM
# 7:00 AM
# 8:00 AM
# 9:00 AM
# 10:00 AM
# 11:00 AM
# Noon
# 1:00 PM
# 2:00 PM
# 3:00 PM
# 4:00 PM
# 5:00 PM
# 6:00 PM
# 7:00 PM
# 8:00 PM
# 9:00 PM
# 10:00 PM
# 11:00 PM
# Midnight

# %%
import matplotlib.pyplot as plt

# Get the frequency of each answer in the 'WorkStart' column
workstart_counts = df['WorkStart'].value_counts()

# Sort the workstart_counts based on the index order of time_list
workstart_counts = workstart_counts.reindex(time_list)

# Create a list of labels for the histogram
labels = time_list

# Create a list of frequencies for the histogram
frequencies = workstart_counts.values.tolist()

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.bar(labels, frequencies)
plt.xlabel('Work Start')
plt.ylabel('Frequency')
plt.title('Work Start Distribution')
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
# Get the frequency of each answer in the 'WorkStart' column
workstart_counts = df['WorkStart'].value_counts()

# Sort the workstart_counts based on the index order of time_list
workstart_counts = workstart_counts.reindex(time_list)

# Calculate the percentage for each item
percentages = workstart_counts / workstart_counts.sum() * 100

# Create a DataFrame with the work start distribution and percentages
table_data = pd.DataFrame({'Work Start': workstart_counts.index, 'Frequency': workstart_counts.values, 'Percentage': percentages})

# Display the table
print(table_data)
# Out:
#           Work Start  Frequency  Percentage
# WorkStart
# 1:00 AM      1:00 AM         17    0.125712
# 2:00 AM      2:00 AM         12    0.088738
# 3:00 AM      3:00 AM         18    0.133107
# 4:00 AM      4:00 AM         31    0.229239
# 5:00 AM      5:00 AM         92    0.680322
# 6:00 AM      6:00 AM        447    3.305480
# 7:00 AM      7:00 AM       1282    9.480145
# 8:00 AM      8:00 AM       2658   19.655402
# 9:00 AM      9:00 AM       3570   26.399468
# 10:00 AM    10:00 AM       3380   24.994454
# 11:00 AM    11:00 AM        772    5.708792
# Noon            Noon        385    2.847001
# 1:00 PM      1:00 PM        165    1.220143
# 2:00 PM      2:00 PM        160    1.183169
# 3:00 PM      3:00 PM         65    0.480663
# 4:00 PM      4:00 PM         94    0.695112
# 5:00 PM      5:00 PM         28    0.207055
# 6:00 PM      6:00 PM         67    0.495452
# 7:00 PM      7:00 PM         38    0.281003
# 8:00 PM      8:00 PM         79    0.584190
# 9:00 PM      9:00 PM         52    0.384530
# 10:00 PM    10:00 PM         64    0.473268
# 11:00 PM    11:00 PM         24    0.177475
# Midnight    Midnight         23    0.170081

# %%
# Get the frequency of each answer in the 'WorkStart' column
job_satisfaction_counts = df['JobSatisfaction'].value_counts()

# Calculate the percentage for each item
percentages = job_satisfaction_counts / job_satisfaction_counts.sum() * 100

# Create a DataFrame with the job satisfaction distribution and percentages
table_data = pd.DataFrame({'Job Satisfaction': job_satisfaction_counts.index, 'Frequency': job_satisfaction_counts.values, 'Percentage': percentages})

# Display the table
print(table_data)
# Out:
#                  Job Satisfaction  Frequency  Percentage
# JobSatisfaction
# 8.0                           8.0       3483   22.834852
# 7.0                           7.0       3087   20.238642
# 9.0                           9.0       2159   14.154593
# 6.0                           6.0       1749   11.466597
# 10.0                         10.0       1529   10.024258
# 5.0                           5.0       1370    8.981840
# 4.0                           4.0        668    4.379466
# 3.0                           3.0        598    3.920540
# 2.0                           2.0        322    2.111060
# 0.0                           0.0        154    1.009637
# 1.0                           1.0        134    0.878516

# %%
home_remote_freq = df['HomeRemote'].value_counts().sort_values(ascending=False)
home_remote_percentage = (df['HomeRemote'].value_counts(normalize=True) * 100).sort_values(ascending=False)

home_remote_unique_responses = df['HomeRemote'].unique()
print('\nUnique responses for HomeRemote:\n', home_remote_unique_responses)
# Out:
# Unique responses for HomeRemote:
#  [nan 'More than half, but not all, the time'
#  'Less than half the time, but at least one day each week' 'Never'
#  "All or almost all the time (I'm full-time remote)" "It's complicated"
#  'A few days each month' 'About half the time']

# %%
# Get the frequency of each answer in the 'HomeRemote' column
homeremote_counts = df['HomeRemote'].value_counts()

# Calculate the percentage for each item
percentages = homeremote_counts / homeremote_counts.sum() * 100

# Create a DataFrame with the home remote distribution and percentages
table_data = pd.DataFrame({'Home Remote': homeremote_counts.index, 'Frequency': homeremote_counts.values, 'Percentage': percentages})

# Display the table
print(table_data)
# Out:
#                                                                                                      Home Remote  \
# HomeRemote
# A few days each month                                                                      A few days each month
# Never                                                                                                      Never
# All or almost all the time (I'm full-time remote)              All or almost all the time (I'm full-time remote)
# Less than half the time, but at least one day each week  Less than half the time, but at least one day each week
# More than half, but not all, the time                                      More than half, but not all, the time
# It's complicated                                                                                It's complicated
# About half the time                                                                          About half the time
#
#                                                          Frequency  Percentage
# HomeRemote
# A few days each month                                         5876   35.674822
# Never                                                         5288   32.104912
# All or almost all the time (I'm full-time remote)             1922   11.668994
# Less than half the time, but at least one day each week       1464    8.888349
# More than half, but not all, the time                          676    4.104183
# It's complicated                                               633    3.843118
# About half the time                                            612    3.715621

# %% [raw]
# Work Environment and Preferences: The Developer's Shire
# We aim to gain insights into the typical working environments of developers, including the size and type of organizations they work for, their work hours, job
# satisfaction, and remote work frequency.
# (I.) What is the size and type of organizations developers work for?
# (J.) What are their working hours and job satisfaction levels?
# (K.) How often do they work remotely?
# (L.) How much is Job Satisfaction influenced by factors such as working hours,career satisfaction and salary?
#
#
# Dive into the diverse world of developers and unearth the secrets behind the curtain. It's a dynamic landscape where private limited companies not in startup mode hold the reigns with an impressive 43.01% of developers pitching their digital tents there. Publicly-traded corporations come next with 15.34% and, intriguingly, 8.06% of developers confessed they're unsure about their company type.
#
# The sizes of these tech gladiators' companies vary greatly, yet a pattern emerges. A bulk of developers - 21.93%, work in relatively smaller firms with 20 to 99 employees. Next up are those in companies with 100 to 499 employees (19.50%) and surprisingly, a good chunk (13.64%) are venturing into the giants' lair, working in companies with 10,000 or more employees.
#
# Pondering over work start times, we find a beautifully predictable human pattern. An extreme minority, the nocturnal code wizards, start work at ungodly hours like 1-5 AM, accounting for less than 1.5% combined. However, the grand bell tolls at 9 AM, the classic start time, with a colossal 26.40% of developers commencing their tech odyssey. Not far behind, with a formidable 24.99%, are the slightly more relaxed breed starting at 10 AM.
#
# Peeking at job satisfaction reveals a generally positive trend, with 22.83% rating their satisfaction at 8/10 and 20.24% at 7/10. The most satisfied lot, those at 10/10, make up 10.02%. A small group, though, do express discontent, with a combined 7.3% rating their satisfaction 4/10 or lower.
#
# Lastly, let's teleport into developers' homes. A sizable 35.67% enjoy the comfort of their homes a few days each month for work, and 32.10% assert they never do. Remote working seems to be fully embraced by 11.67% who work from home all or almost all the time. Yet, remote work policies remain a puzzle for some, with 3.84% stating, "It's complicated."
#
# In conclusion, the developer's world is a fascinating tapestry woven with threads of variety - in company types and sizes, work start times, job satisfaction levels, and home remote policies. The diversity is a testament to the unique experiences and preferences of developers in this digital age.

# %%
print(df['JobSecurity'].unique())
# Out:
# ['Strongly agree' nan 'Agree' 'Somewhat agree' 'Strongly disagree'
#  'Disagree']

# %% [raw]
# JobSatisfaction = CareerSatisfaction, HoursPerWeek, Salary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('/Users/luca/Documents/Udacity - Introduction to Data Science Course Material/survey_results_public.csv')

#Only use quant variables and drop any rows with missing values
num_vars = df[['JobSatisfaction', 'CareerSatisfaction', 'HoursPerWeek', 'Salary']]

#Drop the rows with missing Job Satisfaction answers
drop_jobsatisfaction_df = num_vars.dropna(subset=['JobSatisfaction'], axis=0)

#Mean function
fill_mean = lambda col: col.fillna(col.mean())

#Fill the mean
fill_df = drop_jobsatisfaction_df.apply(fill_mean, axis=0)

#Split into explanatory and response variable
X = fill_df[['CareerSatisfaction', 'HoursPerWeek', 'Salary']]
y = fill_df['JobSatisfaction']

#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state = 42)

#instantiate
lm_model = make_pipeline(StandardScaler(), LinearRegression()) 

#Fit
lm_model.fit(X_train, y_train) 

#Predict and score the model
y_test_preds = lm_model.predict(X_test)
"The r-squared score for the model using only quantitative variables was {} on {} values.".format(r2_score(y_test, y_test_preds), len(y_test))
# Out:
# 'The r-squared score for the model using only quantitative variables was 0.43828220035563215 on 4576 values.'

# %% [raw]
# The constructed linear regression model, which incorporated only quantitative variables namely CareerSatisfaction, HoursPerWeek, and Salary, accounted for approximately 43.83% of the variability in Job Satisfaction amongst the 4576 observations. This suggests that these factors play a substantial role in explaining job satisfaction, but also indicates that a significant proportion (approximately 56.17%) of the variation can be attributed to other factors not included in the current model or inherent stochasticity. Further research is needed to identify and understand these additional influencing factors to enhance our predictive power and comprehension of job satisfaction.
