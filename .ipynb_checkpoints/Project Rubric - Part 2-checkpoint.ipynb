# %% [raw]
# Part 2: Enhancing the Model - Diving Deeper into the Developers' Realm
#
# In the second part of Project Rubric, we will focus on expanding the boundaries of our analysis by including both numerical and categorical data in our study, thereby extending the reach of our linear regression model. This will allow us to draw more intricate and detailed conclusions from our dataset.
#
# Objective
# Advanced Regression Modelling: Predicting Job Satisfaction
#
# We will build upon the linear regression model from part 1, but this time, both numerical and categorical data will be included in the model. The model will focus on predicting job satisfaction from various developer characteristics.

# %%
#importing necessary libs

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing


df = pd.read_csv('/Users/luca/Documents/Project Rubric/Data Part 2/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %%
#Before we proceed, we need to handle missing data. First, check the amount of missing data in the columns:

pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# Respondent                              0
# Professional                            0
# ProgramHobby                            0
# Country                                 0
# University                              0
# EmploymentStatus                        0
# FormalEducation                         0
# MajorUndergrad                       3203
# HomeRemote                           2631
# CompanySize                          4449
# CompanyType                          4493
# YearsProgram                           97
# YearsCodedJob                        3711
# YearsCodedJobPast                   18753
# DeveloperType                        5330
# WebDeveloperType                    14816
# MobileDeveloperType                 18546
# NonDeveloperType                    17414
# CareerSatisfaction                   3000
# JobSatisfaction                      3849
# ExCoderReturn                       18767
# ExCoderNotForMe                     18770
# ExCoderBalance                      18767
# ExCoder10Years                      18766
# ExCoderBelonged                     18767
# ExCoderSkills                       18766
# ExCoderWillNotCode                  18770
# ExCoderActive                       18767
# PronounceGIF                          162
# ProblemSolving                       6882
# BuildingThings                       6901
# LearningNewTech                      6886
# BoringDetails                        6912
# JobSecurity                          6904
# DiversityImportant                   7023
# AnnoyingUI                           6962
# FriendsDevelopers                    6959
# RightWrongWay                        6990
# UnderstandComputers                  6967
# SeriousWork                          6970
# InvestTimeTools                      7043
# WorkPayCare                          7015
# KinshipDevelopers                    7122
# ChallengeMyself                      7013
# CompetePeers                         7068
# ChangeWorld                          7025
# JobSeekingStatus                     6250
# HoursPerWeek                        11381
# LastNewJob                           6524
# AssessJobIndustry                   10701
# AssessJobRole                       10699
# AssessJobExp                        10704
# AssessJobDept                       10712
# AssessJobTech                       10682
# AssessJobProjects                   10690
# AssessJobCompensation               10695
# AssessJobOffice                     10766
# AssessJobCommute                    10771
# AssessJobRemote                     10751
# AssessJobLeaders                    10772
# AssessJobProfDevel                  10761
# AssessJobDiversity                  10778
# AssessJobProduct                    10768
# AssessJobFinances                   10751
# ImportantBenefits                    7532
# ClickyKeys                           3744
# JobProfile                           9912
# ResumePrompted                      10398
# LearnedHiring                        9919
# ImportantHiringAlgorithms            8212
# ImportantHiringTechExp               8208
# ImportantHiringCommunication         8223
# ImportantHiringOpenSource            8238
# ImportantHiringPMExp                 8233
# ImportantHiringCompanies             8251
# ImportantHiringTitles                8243
# ImportantHiringEducation             8219
# ImportantHiringRep                   8224
# ImportantHiringGettingThingsDone     8253
# Currency                            11070
# Overpaid                            13918
# TabsSpaces                           4797
# EducationImportant                  10037
# EducationTypes                       7637
# SelfTaughtTypes                      8929
# TimeAfterBootcamp                   18220
# CousinEducation                     12196
# WorkStart                            5579
# HaveWorkedLanguage                   5576
# WantWorkLanguage                     6579
# HaveWorkedFramework                 11808
# WantWorkFramework                   10603
# HaveWorkedDatabase                   8310
# WantWorkDatabase                     9943
# HaveWorkedPlatform                   8522
# WantWorkPlatform                     8944
# IDE                                  5905
# AuditoryEnvironment                  5651
# Methodology                          9515
# VersionControl                       7531
# CheckInCode                          7898
# ShipIt                               7893
# OtherPeoplesCode                     7900
# ProjectManagement                    7980
# EnjoyDebugging                       7844
# InTheZone                            8001
# DifficultCommunication               7892
# CollaborateRemote                    7972
# MetricAssess                         9477
# EquipmentSatisfiedMonitors           7972
# EquipmentSatisfiedCPU                7975
# EquipmentSatisfiedRAM                7969
# EquipmentSatisfiedStorage            8002
# EquipmentSatisfiedRW                 7992
# InfluenceInternet                    7996
# InfluenceWorkstation                10840
# InfluenceHardware                   10840
# InfluenceServers                    10863
# InfluenceTechStack                  10849
# InfluenceDeptTech                   10859
# InfluenceVizTools                   10858
# InfluenceDatabase                   10847
# InfluenceCloud                      10859
# InfluenceConsultants                10873
# InfluenceRecruitment                10858
# InfluenceCommunication              10852
# StackOverflowDescribes               5546
# StackOverflowSatisfaction            5650
# StackOverflowDevices                 6156
# StackOverflowFoundAnswer             6411
# StackOverflowCopiedCode              6525
# StackOverflowJobListing              6677
# StackOverflowCompanyPage             6691
# StackOverflowJobSearch               6695
# StackOverflowNewQuestion             6630
# StackOverflowAnswer                  6657
# StackOverflowMetaChat                6688
# StackOverflowAdsRelevant             7575
# StackOverflowAdsDistracting          7261
# StackOverflowModeration              7766
# StackOverflowCommunity               7038
# StackOverflowHelpful                 6560
# StackOverflowBetter                  6640
# StackOverflowWhatDo                  6717
# StackOverflowMakeMoney               7434
# Gender                               6192
# HighestEducationParents              6249
# Race                                 6884
# SurveyLong                           6299
# QuestionsInteresting                 6366
# QuestionsConfusing                   6396
# InterestedAnswers                    6342
# Salary                              14093
# ExpectedSalary                      18284
# dtype: int64

# %%
#CompanySize: There are quite a few missing values here. I will fill these missing values with the mode of the column.
df['CompanySize'].fillna(df['CompanySize'].mode()[0], inplace=True)

#HoursPerWeek: This column seems to have a lot of missing values. It's likely that these missing values are because not all survey respondents work or 
#they chose not to provide this information. We will fill the missing values with the median of the non-missing responses
df['HoursPerWeek'].fillna(df['HoursPerWeek'].median(), inplace=True)

#HomeRemote: For this column, we will use the mode to fill the missing values.
df['HomeRemote'].fillna(df['HomeRemote'].mode()[0], inplace=True)

#JobSecurity: For the 'JobSecurity' column, let's use the mode as well.
df['JobSecurity'].fillna(df['JobSecurity'].mode()[0], inplace=True)

#JobSatisfaction: we remove the rows with missing 'JobSatisfaction'
df = df[~df['JobSatisfaction'].isnull()]

#Salary: We will fill the missing values with the mean.
df['Salary'].fillna(df['Salary'].mean(), inplace=True)

#CareerSatisfaction: We will fill the missing values with the mean.
df['CareerSatisfaction'].fillna(df['CareerSatisfaction'].mean(), inplace=True)

# Gender: we will fill missing values in the 'Gender' column with 'Unknown'.
df['Gender'].fillna('Unknown', inplace=True)

# %%
df[['CompanySize', 'HoursPerWeek', 'HomeRemote', 'JobSecurity','Gender', 'Salary', 'CareerSatisfaction']].head()
# Out:
#                 CompanySize  HoursPerWeek  \
# 2  10,000 or more employees           1.0
# 3  10,000 or more employees           5.0
# 4        10 to 19 employees           1.0
# 6        20 to 99 employees           1.0
# 7   Fewer than 10 employees           1.0
#
#                                           HomeRemote     JobSecurity   Gender  \
# 2  Less than half the time, but at least one day ...           Agree     Male
# 3  Less than half the time, but at least one day ...  Somewhat agree     Male
# 4                                              Never           Agree  Unknown
# 6  Less than half the time, but at least one day ...           Agree     Male
# 7  All or almost all the time (I'm full-time remote)           Agree     Male
#
#           Salary  CareerSatisfaction
# 2  113750.000000                 8.0
# 3   58266.522402                 6.0
# 4   58266.522402                 6.0
# 6   58266.522402                 7.0
# 7   58266.522402                 7.0

# %%
#Check the number of missing values for relevant columns
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# Respondent                              0
# Professional                            0
# ProgramHobby                            0
# Country                                 0
# University                              0
# EmploymentStatus                        0
# FormalEducation                         0
# MajorUndergrad                       1325
# HomeRemote                              0
# CompanySize                             0
# CompanyType                          1633
# YearsProgram                           42
# YearsCodedJob                         384
# YearsCodedJobPast                   14991
# DeveloperType                        1892
# WebDeveloperType                    11081
# MobileDeveloperType                 14712
# NonDeveloperType                    13709
# CareerSatisfaction                      0
# JobSatisfaction                         0
# ExCoderReturn                       15003
# ExCoderNotForMe                     15007
# ExCoderBalance                      15003
# ExCoder10Years                      15001
# ExCoderBelonged                     15002
# ExCoderSkills                       15003
# ExCoderWillNotCode                  15005
# ExCoderActive                       15004
# PronounceGIF                           77
# ProblemSolving                       5176
# BuildingThings                       5189
# LearningNewTech                      5177
# BoringDetails                        5187
# JobSecurity                             0
# DiversityImportant                   5273
# AnnoyingUI                           5233
# FriendsDevelopers                    5225
# RightWrongWay                        5254
# UnderstandComputers                  5238
# SeriousWork                          5232
# InvestTimeTools                      5279
# WorkPayCare                          5260
# KinshipDevelopers                    5334
# ChallengeMyself                      5262
# CompetePeers                         5298
# ChangeWorld                          5269
# JobSeekingStatus                     4723
# HoursPerWeek                            0
# LastNewJob                           4886
# AssessJobIndustry                    8285
# AssessJobRole                        8279
# AssessJobExp                         8286
# AssessJobDept                        8296
# AssessJobTech                        8269
# AssessJobProjects                    8274
# AssessJobCompensation                8274
# AssessJobOffice                      8339
# AssessJobCommute                     8339
# AssessJobRemote                      8322
# AssessJobLeaders                     8334
# AssessJobProfDevel                   8329
# AssessJobDiversity                   8344
# AssessJobProduct                     8338
# AssessJobFinances                    8325
# ImportantBenefits                    5601
# ClickyKeys                           2484
# JobProfile                           7236
# ResumePrompted                       6746
# LearnedHiring                        6558
# ImportantHiringAlgorithms            6115
# ImportantHiringTechExp               6110
# ImportantHiringCommunication         6121
# ImportantHiringOpenSource            6125
# ImportantHiringPMExp                 6127
# ImportantHiringCompanies             6146
# ImportantHiringTitles                6143
# ImportantHiringEducation             6118
# ImportantHiringRep                   6125
# ImportantHiringGettingThingsDone     6142
# Currency                             8495
# Overpaid                            10081
# TabsSpaces                           3274
# EducationImportant                   6417
# EducationTypes                       5632
# SelfTaughtTypes                      6633
# TimeAfterBootcamp                   14494
# CousinEducation                      9491
# WorkStart                            3870
# HaveWorkedLanguage                   3847
# WantWorkLanguage                     4731
# HaveWorkedFramework                  8846
# WantWorkFramework                    7858
# HaveWorkedDatabase                   5807
# WantWorkDatabase                     7338
# HaveWorkedPlatform                   6343
# WantWorkPlatform                     6686
# IDE                                  4101
# AuditoryEnvironment                  3932
# Methodology                          6788
# VersionControl                       5638
# CheckInCode                          5725
# ShipIt                               5867
# OtherPeoplesCode                     5864
# ProjectManagement                    5894
# EnjoyDebugging                       5848
# InTheZone                            5967
# DifficultCommunication               5853
# CollaborateRemote                    5912
# MetricAssess                         7194
# EquipmentSatisfiedMonitors           5987
# EquipmentSatisfiedCPU                5991
# EquipmentSatisfiedRAM                5981
# EquipmentSatisfiedStorage            6016
# EquipmentSatisfiedRW                 6001
# InfluenceInternet                    6004
# InfluenceWorkstation                 7366
# InfluenceHardware                    7365
# InfluenceServers                     7387
# InfluenceTechStack                   7373
# InfluenceDeptTech                    7382
# InfluenceVizTools                    7385
# InfluenceDatabase                    7372
# InfluenceCloud                       7386
# InfluenceConsultants                 7399
# InfluenceRecruitment                 7381
# InfluenceCommunication               7378
# StackOverflowDescribes               3863
# StackOverflowSatisfaction            3931
# StackOverflowDevices                 4339
# StackOverflowFoundAnswer             4536
# StackOverflowCopiedCode              4628
# StackOverflowJobListing              4749
# StackOverflowCompanyPage             4749
# StackOverflowJobSearch               4760
# StackOverflowNewQuestion             4722
# StackOverflowAnswer                  4730
# StackOverflowMetaChat                4753
# StackOverflowAdsRelevant             5499
# StackOverflowAdsDistracting          5240
# StackOverflowModeration              5663
# StackOverflowCommunity               5062
# StackOverflowHelpful                 4674
# StackOverflowBetter                  4737
# StackOverflowWhatDo                  4795
# StackOverflowMakeMoney               5395
# Gender                                  0
# HighestEducationParents              4400
# Race                                 4931
# SurveyLong                           4458
# QuestionsInteresting                 4516
# QuestionsConfusing                   4540
# InterestedAnswers                    4494
# Salary                                  0
# ExpectedSalary                      15253
# dtype: int64

# %%
#Here I want to get an overview of the answer respondents could potentialy give to the various questions.
# Possible answers for 'CompanySize'
company_size_answers = df['CompanySize'].value_counts().index.tolist()
print("Possible Company Sizes:")
for answer in company_size_answers:
    print(answer)

# Possible answers for 'HomeRemote'
home_remote_answers = df['HomeRemote'].value_counts().index.tolist()
print("\nPossible Home Remote Options:")
for answer in home_remote_answers:
    print(answer)

# Possible answers for 'JobSecurity'
job_security_answers = df['JobSecurity'].value_counts().index.tolist()
print("\nPossible Job Security Options:")
for answer in job_security_answers:
    print(answer)

# Possible answers for 'Gender'
unique_genders = set()
for gender in df['Gender']:
    if pd.notnull(gender):
        unique_genders.update(gender.split(';'))

print("\nPossible Genders:")
for gender in unique_genders:
    print(gender.strip())
# Out:
# Possible Company Sizes:
# 20 to 99 employees
# 100 to 499 employees
# 10,000 or more employees
# 10 to 19 employees
# 1,000 to 4,999 employees
# Fewer than 10 employees
# 500 to 999 employees
# 5,000 to 9,999 employees
# I don't know
# I prefer not to answer
#
# Possible Home Remote Options:
# A few days each month
# Never
# All or almost all the time (I'm full-time remote)
# Less than half the time, but at least one day each week
# It's complicated
# More than half, but not all, the time
# About half the time
#
# Possible Job Security Options:
# Agree
# Somewhat agree
# Strongly agree
# Disagree
# Strongly disagree
#
# Possible Genders:
# Female
# Other
# Transgender
# Other
# Gender non-conforming
# Male
# Female
# Unknown
# Gender non-conforming
# Transgender

# %%
#Here we will convert the categorical data to numerical data, create new columns and ad them to the df
# Define the mapping of possible answers to scores for each column
company_size_mapping = {
    "I don't know": 1,
    'Fewer than 10 employees': 2,
    '10 to 19 employees': 3,
    '20 to 99 employees': 4,
    '100 to 499 employees': 5,
    '500 to 999 employees': 6,
    '1,000 to 4,999 employees': 7,
    '5,000 to 9,999 employees': 8,
    '10,000 or more employees': 9,
    'I prefer not to answer': 10
}

home_remote_mapping = {
    'Never': 1,
    "It's complicated": 2,
    'A few days each month': 3,
    'Less than half the time, but at least one day each week': 4,
    'About half the time': 5,
    'More than half, but not all, the time': 6,
    'All or almost all the time (I\'m full-time remote)': 7
}

job_security_mapping = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Somewhat agree': 3,
    'Agree': 4,
    'Strongly agree': 5
}

gender_mapping = {
    'Unknown': 1,
    'Male': 2,
    'Female': 3,
    'Transgender': 4,
    'Gender non-conforming': 5,
    'Other': 6
}

# Add the new columns to the DataFrame
df['CompanySize_int'] = df['CompanySize'].map(company_size_mapping)
df['HomeRemote_int'] = df['HomeRemote'].map(home_remote_mapping)
df['JobSecurity_int'] = df['JobSecurity'].map(job_security_mapping) # Corrected column name
df['Gender_int'] = df['Gender'].map(gender_mapping)

# Script to check the presence of the new columns in df
new_columns = ['CompanySize_int', 'HomeRemote_int', 'JobSecurity_int', 'Gender_int'] # Corrected column name
missing_columns = [col for col in new_columns if col not in df.columns]

if len(missing_columns) == 0:
    print("The new columns have been successfully added to df.")
else:
    print("The following columns are missing in df:", missing_columns)
# Out:
# The new columns have been successfully added to df.

# %%
# Copy the content of the columns to the new columns ending with '_int'
df['CompanySize_int'] = df['CompanySize']
df['HomeRemote_int'] = df['HomeRemote']
df['Job_Security_int'] = df['JobSecurity']
df['Gender_int'] = df['Gender']

# Display the first 5 rows of all the new columns ending with '_int'
new_columns = ['CompanySize_int', 'HomeRemote_int', 'JobSecurity_int', 'Gender_int']
new_columns_data = df[new_columns].head(50)
print(new_columns_data)
# Out:
#              CompanySize_int  \
# 2   10,000 or more employees
# 3   10,000 or more employees
# 6         20 to 99 employees
# 7    Fewer than 10 employees
# 8   5,000 to 9,999 employees
# 9         20 to 99 employees
# 10      100 to 499 employees
# 13   Fewer than 10 employees
# 14  5,000 to 9,999 employees
# 15        20 to 99 employees
# 17  1,000 to 4,999 employees
# 19   Fewer than 10 employees
# 21        20 to 99 employees
# 22      500 to 999 employees
# 23        20 to 99 employees
# 25  10,000 or more employees
# 28        10 to 19 employees
# 33        20 to 99 employees
# 34        10 to 19 employees
# 35   Fewer than 10 employees
# 36      500 to 999 employees
# 38        20 to 99 employees
# 40  1,000 to 4,999 employees
# 42      100 to 499 employees
# 44  10,000 or more employees
# 47      500 to 999 employees
# 48        10 to 19 employees
# 49        20 to 99 employees
# 50        20 to 99 employees
# 51  10,000 or more employees
# 52  1,000 to 4,999 employees
# 53   Fewer than 10 employees
# 54  1,000 to 4,999 employees
# 55   Fewer than 10 employees
# 57      100 to 499 employees
# 58  1,000 to 4,999 employees
# 60  10,000 or more employees
# 61  5,000 to 9,999 employees
# 62        20 to 99 employees
# 64  10,000 or more employees
# 65        20 to 99 employees
# 66  5,000 to 9,999 employees
# 67  10,000 or more employees
# 68      100 to 499 employees
# 70        20 to 99 employees
# 71        20 to 99 employees
# 72      100 to 499 employees
# 73      500 to 999 employees
# 75      500 to 999 employees
# 76  1,000 to 4,999 employees
#
#                                        HomeRemote_int  JobSecurity_int  \
# 2   Less than half the time, but at least one day ...                4
# 3   Less than half the time, but at least one day ...                3
# 6   Less than half the time, but at least one day ...                4
# 7   All or almost all the time (I'm full-time remote)                4
# 8   Less than half the time, but at least one day ...                4
# 9                                    It's complicated                4
# 10  All or almost all the time (I'm full-time remote)                4
# 13  Less than half the time, but at least one day ...                4
# 14  All or almost all the time (I'm full-time remote)                3
# 15  All or almost all the time (I'm full-time remote)                3
# 17  All or almost all the time (I'm full-time remote)                4
# 19  Less than half the time, but at least one day ...                3
# 21                              A few days each month                4
# 22                              A few days each month                4
# 23  All or almost all the time (I'm full-time remote)                4
# 25  Less than half the time, but at least one day ...                4
# 28                              A few days each month                1
# 33  All or almost all the time (I'm full-time remote)                4
# 34                              A few days each month                4
# 35                                              Never                3
# 36                              A few days each month                4
# 38              More than half, but not all, the time                4
# 40  All or almost all the time (I'm full-time remote)                4
# 42                                              Never                4
# 44                              A few days each month                3
# 47                              A few days each month                4
# 48                                About half the time                4
# 49                              A few days each month                5
# 50                                              Never                5
# 51  Less than half the time, but at least one day ...                5
# 52                              A few days each month                5
# 53                              A few days each month                4
# 54                              A few days each month                4
# 55                                              Never                4
# 57                              A few days each month                4
# 58  Less than half the time, but at least one day ...                5
# 60                                   It's complicated                4
# 61                              A few days each month                5
# 62  All or almost all the time (I'm full-time remote)                2
# 64                              A few days each month                3
# 65                                              Never                3
# 66              More than half, but not all, the time                4
# 67                              A few days each month                3
# 68                                              Never                4
# 70                              A few days each month                4
# 71                              A few days each month                4
# 72  All or almost all the time (I'm full-time remote)                5
# 73                                              Never                4
# 75                                              Never                4
# 76              More than half, but not all, the time                5
#
#    Gender_int
# 2        Male
# 3        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10     Female
# 13     Female
# 14       Male
# 15       Male
# 17       Male
# 19       Male
# 21       Male
# 22       Male
# 23       Male
# 25       Male
# 28       Male
# 33       Male
# 34       Male
# 35       Male
# 36       Male
# 38       Male
# 40       Male
# 42       Male
# 44       Male
# 47       Male
# 48       Male
# 49       Male
# 50       Male
# 51       Male
# 52       Male
# 53       Male
# 54       Male
# 55       Male
# 57       Male
# 58       Male
# 60       Male
# 61       Male
# 62       Male
# 64       Male
# 65       Male
# 66       Male
# 67       Male
# 68       Male
# 70       Male
# 71       Male
# 72       Male
# 73       Male
# 75       Male
# 76       Male

# %%
# Define the mapping of values to new values for each column
company_size_conversion = {
    "I don't know": 1,
    'Fewer than 10 employees': 2,
    '10 to 19 employees': 3,
    '20 to 99 employees': 4,
    '100 to 499 employees': 5,
    '500 to 999 employees': 6,
    '1,000 to 4,999 employees': 7,
    '5,000 to 9,999 employees': 8,
    '10,000 or more employees': 9,
    'I prefer not to answer': 10
}

home_remote_conversion = {
    'Never': 1,
    "It's complicated": 2,
    'A few days each month': 3,
    'Less than half the time, but at least one day each week': 4,
    'About half the time': 5,
    'More than half, but not all, the time': 6,
    'All or almost all the time (I\'m full-time remote)': 7
}

job_security_conversion = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Somewhat agree': 3,
    'Agree': 4,
    'Strongly agree': 5
}

gender_conversion = {
    'Unknown': 1,
    'Male': 2,
    'Female': 3,
    'Transgender': 4,
    'Gender non-conforming': 5,
    'Other': 6
}

# Create new columns
df['CompanySize_int'] = df['CompanySize']
df['HomeRemote_int'] = df['HomeRemote']
df['JobSecurity_int'] = df['JobSecurity']
df['Gender_int'] = df['Gender']

# Convert the content of the new columns based on the provided logic
df['CompanySize_int'] = df['CompanySize_int'].map(company_size_conversion)
df['HomeRemote_int'] = df['HomeRemote_int'].map(home_remote_conversion)
df['JobSecurity_int'] = df['JobSecurity_int'].map(job_security_conversion)
df['Gender_int'] = df['Gender_int'].map(gender_conversion)

# Display the first 400 rows of all the new columns ending with '_int'
new_columns = ['CompanySize_int', 'HomeRemote_int', 'JobSecurity_int', 'Gender_int']
new_columns_data = df[new_columns].head(5)
print(new_columns_data)
# Out:
#    CompanySize_int  HomeRemote_int  JobSecurity_int  Gender_int
# 2                9               4                4         2.0
# 3                9               4                3         2.0
# 4                3               1                4         1.0
# 6                4               4                4         2.0
# 7                2               7                4         2.0

# %%
df[['CompanySize_int','HomeRemote_int', 'JobSecurity_int','Gender_int']].head(5)
# Out:
#    CompanySize_int  HomeRemote_int  JobSecurity_int  Gender_int
# 2                9               4                4         2.0
# 3                9               4                3         2.0
# 4                3               1                4         1.0
# 6                4               4                4         2.0
# 7                2               7                4         2.0

# %%
# Replace NaN values with the mean for CompanySize_int, HomeRemote_int, and JobSecurity_int
df['CompanySize_int'].fillna(df['CompanySize_int'].mean(), inplace=True)
df['HomeRemote_int'].fillna(df['HomeRemote_int'].mean(), inplace=True)
df['JobSecurity_int'].fillna(df['JobSecurity_int'].mean(), inplace=True)

# Drop rows with NaN values for Gender_int
df.dropna(subset=['Gender_int'], inplace=True)

# Replace NaN values with the mean for HoursPerWeek and CareerSatisfaction
df['HoursPerWeek'].fillna(df['HoursPerWeek'].mean(), inplace=True)
df['CareerSatisfaction'].fillna(df['CareerSatisfaction'].mean(), inplace=True)

# Replace NaN values with the median for Salary
df['Salary'].fillna(df['Salary'].median(), inplace=True)

# %%
nan_counts = df[['CompanySize_int', 'HomeRemote_int', 'JobSecurity_int', 'HoursPerWeek', 'Salary', 'CareerSatisfaction', 'Gender_int']].isnull().sum()
print(nan_counts)
# Out:
# CompanySize_int       0
# HomeRemote_int        0
# JobSecurity_int       0
# HoursPerWeek          0
# Salary                0
# CareerSatisfaction    0
# Gender_int            0
# dtype: int64

# %%
#We will now split the data into a training set and a test set.
#Separate our target variable 'JobSatisfaction' from the rest of the DataFrame and then split the data

from sklearn.model_selection import train_test_split

# Define predictors
X = df[['CompanySize_int', 'HoursPerWeek', 'HomeRemote_int', 'JobSecurity_int','Gender_int', 'Salary', 'CareerSatisfaction']]

# Define target
y = df['JobSatisfaction']

# Split the data (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Train hte linear regression model on the training data and then use it to make predictions on the test data. 
#We will use the Linear Regression model from the sklearn.linear_model library.

from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
lm = LinearRegression()

# Train the model using our training data
lm.fit(X_train, y_train)

#This will create a Linear Regression model and train it on our training data.
# Out:
# LinearRegression()

# %%
#We will use the trained model to make predictions on our test data, and 
#compare these predictions to the actual values to see how well our model is performing

# Use the model to make predictions on the test data
y_pred = lm.predict(X_test)


#y_pred will be a list of predicted 'JobSatisfaction' values corresponding to the predictors in X_test.

# %%
#To evaluate how well the model performed, we calculate the RMSE, 
#to identify the average distance between the predicted and actual values:


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(y_test, y_pred))

print("RMSE: ", rmse)
# Out:
# RMSE:  1.5840759713432377

# %%
# Get the R-squared value
r2_train = lm.score(X_train, y_train)
r2_test = lm.score(X_test, y_test)

print(f'R-squared for training data: {r2_train}')
print(f'R-squared for testing data: {r2_test}')
# Out:
# R-squared for training data: 0.4277120667665867
# R-squared for testing data: 0.45626223125810084

# %% [raw]
# In this amalysis, we successfully developed a linear regression model to examine and predict job satisfaction based on a series of predictors, which included 'CompanySize', 'HoursPerWeek', 'HomeRemote', 'JobSecurity', 'Salary', 'CareerSatisfaction', and 'Gender'. The constructed model was rigorously trained and tested and demonstrated its ability to predict job satisfaction with a coefficient of determination (R-squared) of approximately 0.40 for both the training and testing datasets. This implies that our model is able to explain approximately 40% of the variation in job satisfaction, a significant portion given the complex nature of the construct. Therefore, this study provides valuable insights into the multifaceted nature of job satisfaction and offers a predictive model with robust performance, contributing to the broader field of workplace satisfaction research.

# %% [raw]
# In pursuit of a deeper understanding of the multifaceted dynamics of job satisfaction, a comprehensive linear regression model was meticulously crafted. This model incorporates a broad spectrum of predictors, including 'CompanySize', 'HoursPerWeek', 'HomeRemote', 'JobSecurity', 'Salary', 'CareerSatisfaction', and 'Gender', to illuminate this critical aspect of workplace culture.
#
# Through a rigorous process of training and testing, the model showed promise, registering a coefficient of determination (R-squared) of around 0.40 for both the training and testing datasets. This achievement suggests that the model can explain close to 40% of the variation in job satisfaction, which is quite significant, given the complex nature of this construct.
#
# Nonetheless, it is acknowledged that the model, while effective, is not without its room for improvement. There exists potential for further fine-tuning, which could enhance its predictive power even more. This is seen not as a limitation, but rather as an exciting avenue for continued learning and refinement.
#
# This study, while not holding all the answers, provides valuable insights into the nuanced concept of job satisfaction. By offering a predictive model with solid performance, it aims to serve as a catalyst for further exploration in the broad field of workplace satisfaction research. The hope is that this contribution can be a stepping stone towards an enriched understanding of job satisfaction.
